# %%
import xarray as xr
import glob
from dask.diagnostics import ProgressBar
import numpy as np

# %% [markdown]
# # TODO: Same P, T plots with The ML ensemble

# %%
files = glob.glob(r'//nesi/nobackup/niwa00018/MfE_data_12km/pr*historical*raw.nc')

files = [file for file in files if not (("ERA5" in file) |("NZESM" in file)) ]
print(len(files))
# Out:
# 6

# %%
dfs = []
for file in files:
    print(file)
    with ProgressBar():
        df = xr.open_dataset(file, chunks ={"time":5000}).load()
    seasonal_climo = df.sel(time = slice('1986','2005')).groupby('time.season').mean().rename({"pr":"seasonal_pr_hist"})
    rx1day = df.groupby('time.year').max().rename({"pr":"Rx1day"})
    concat_dset = xr.merge([seasonal_climo, rx1day])
    concat_dset = concat_dset.expand_dims({"GCM":1})
    gcm = file.split('/')[-1].split('_')[2]
    concat_dset['GCM'] = (('GCM'), [gcm])
    dfs.append(concat_dset)
# Out:
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_historical_NorESM2-MM_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 7.07 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_historical_ACCESS-CM2_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 6.07 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_historical_AWI-CM-1-1-MR_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 6.56 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_historical_EC-Earth3_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 6.37 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_historical_GFDL-ESM4_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 7.28 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_historical_CNRM-CM6-1_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 5.66 sms

# %%
df_hist = xr.concat(dfs, dim ="GCM")

# %%
files_future = glob.glob(r'//nesi/nobackup/niwa00018/MfE_data_12km/pr*ssp370*raw.nc')
print(len(files))
files_future = [file for file in files_future if not (("ERA5" in file) |("NZESM" in file)) ]
# Out:
# 6

# %%
files_future
# Out:
# ['//nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_ACCESS-CM2_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_AWI-CM-1-1-MR_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_GFDL-ESM4_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_NorESM2-MM_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_EC-Earth3_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_CNRM-CM6-1_CCAM_daily_NZ12km_raw.nc']

# %%
dfs = []
for file in files_future:
    print(file)
    with ProgressBar():
        df = xr.open_dataset(file, chunks ={"time":5000}).load()
    seasonal_climo = df.sel(time = slice('2080','2099')).groupby('time.season').mean().rename({"pr":"seasonal_pr_future"})
    rx1day = df.groupby('time.year').max().rename({"pr":"Rx1day"})
    concat_dset = xr.merge([seasonal_climo, rx1day])
    concat_dset = concat_dset.expand_dims({"GCM":1})
    gcm = file.split('/')[-1].split('_')[2]
    concat_dset['GCM'] = (('GCM'), [gcm])
    dfs.append(concat_dset)
# Out:
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_ACCESS-CM2_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 10.56 ss
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_AWI-CM-1-1-MR_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 10.29 ss
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_GFDL-ESM4_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 10.38 ss
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_NorESM2-MM_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 9.48 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_EC-Earth3_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 7.37 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/pr_ssp370_CNRM-CM6-1_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 11.40 ss

# %%
df_future = xr.concat(dfs, dim ="GCM")

# %%
files_future = glob.glob(r'//nesi/nobackup/niwa00018/MfE_data_12km/tasmax*ssp370*raw.nc')
print(len(files))
files_future = [file for file in files_future if not (("ERA5" in file) |("NZESM" in file)) ]
# Out:
# 6

# %%
files_future
# Out:
# ['//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_ACCESS-CM2_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_EC-Earth3_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_NorESM2-MM_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_CNRM-CM6-1_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_AWI-CM-1-1-MR_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_GFDL-ESM4_CCAM_daily_NZ12km_raw.nc']

# %%
dfs = []
for file in files_future:
    print(file)
    with ProgressBar():
        df = xr.open_dataset(file, chunks ={"time":5000}).load()
    seasonal_climo = df.sel(time = slice('2080','2099')).groupby('time.season').mean().rename({"tasmax":"seasonal_tasmax_future"})
    rx1day = df.groupby('time.year').max().rename({"tasmax":"TXx"})
    concat_dset = xr.merge([seasonal_climo, rx1day])
    concat_dset = concat_dset.expand_dims({"GCM":1})
    gcm = file.split('/')[-1].split('_')[2]
    concat_dset['GCM'] = (('GCM'), [gcm])
    dfs.append(concat_dset)
# Out:
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_ACCESS-CM2_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 5.36 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_EC-Earth3_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 6.51 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_NorESM2-MM_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 5.46 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_CNRM-CM6-1_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 5.08 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_AWI-CM-1-1-MR_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 5.40 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_ssp370_GFDL-ESM4_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 5.94 sms

# %%
df_future_tasmax = xr.concat(dfs, dim ="GCM")

# %%
files = glob.glob(r'//nesi/nobackup/niwa00018/MfE_data_12km/tasmax*historical*raw.nc')
print(len(files))
files= [file for file in files if not (("ERA5" in file) |("NZESM" in file)) ]
# Out:
# 8

# %%
files
# Out:
# ['//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_GFDL-ESM4_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_CNRM-CM6-1_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_NorESM2-MM_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_AWI-CM-1-1-MR_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_EC-Earth3_CCAM_daily_NZ12km_raw.nc',
#  '//nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_ACCESS-CM2_CCAM_daily_NZ12km_raw.nc']

# %%
dfs = []
for file in files:
    print(file)
    with ProgressBar():
        df = xr.open_dataset(file, chunks ={"time":5000}).load()
    seasonal_climo = df.sel(time = slice('1986','2005')).groupby('time.season').mean().rename({"tasmax":"seasonal_tasmax"})
    rx1day = df.groupby('time.year').max().rename({"tasmax":"TXx"})
    concat_dset = xr.merge([seasonal_climo, rx1day])
    concat_dset = concat_dset.expand_dims({"GCM":1})
    gcm = file.split('/')[-1].split('_')[2]
    concat_dset['GCM'] = (('GCM'), [gcm])
    dfs.append(concat_dset)
# Out:
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_GFDL-ESM4_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 3.28 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_CNRM-CM6-1_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 3.67 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_NorESM2-MM_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 3.96 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_AWI-CM-1-1-MR_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 4.83 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_EC-Earth3_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 3.99 sms
# //nesi/nobackup/niwa00018/MfE_data_12km/tasmax_historical_ACCESS-CM2_CCAM_daily_NZ12km_raw.nc
# [########################################] | 100% Completed | 4.99 sms

# %%
df_hist_tasmax = xr.concat(dfs, dim ="GCM")

# %%
Txx = xr.concat([df_hist_tasmax.TXx, df_future_tasmax.TXx], dim ="year").to_dataset()

# %%
merged_T = xr.merge([Txx, df_future_tasmax.seasonal_tasmax_future, df_hist_tasmax.seasonal_tasmax])

# %%
Rx1day = xr.concat([df_hist.Rx1day*86400, df_future.Rx1day*86400], dim ="year").to_dataset()

# %%
merged_P = xr.merge([Rx1day , df_future.seasonal_pr_future, df_hist.seasonal_pr_hist])

# %%
All_merged = xr.merge([merged_P, merged_T])

# %%
All_merged = All_merged.rename({"seasonal_tasmax":"seasonal_tasmax_hist"})

# %%
All_merged.to_netcdf(r'/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/CCAM_P_T_indicators_final.nc')

# %%
All_merged_CCAM = xr.open_dataset(r'/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/CCAM_P_T_indicators_final.nc')

# %%
files_glob_tx = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_*ssp370*_day_NZ12km_NIWA-REMS_tasmax_v280125.nc')
#files_glob_pr = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/{ssp}/daily/pr/pr_ScenarioMIP_*{ssp}*_day_NZ12km_NIWA-REMS_pr_v280125.nc')
ssp_dset = []
for file in files_glob_tx:
    print(file)
    with ProgressBar():
        df = xr.open_dataset(file, chunks ={"time":5000}).load()
    seasonal_climo = df.sel(time = slice('2080','2099')).groupby('time.season').mean().rename({"tasmax":"seasonal_tasmax"})
    rx1day = df.groupby('time.year').max().rename({"tasmax":"TXx"})
    concat_dset = xr.merge([seasonal_climo, rx1day])
    concat_dset = concat_dset.expand_dims({"GCM_variant":1})
    variant = file.split('/')[-1].split('_')[5]
    ssp = file.split('/')[-1].split('_')[4]
    gcm = file.split('/')[-1].split('_')[3]
    concat_dset['GCM_variant'] = (('GCM_variant'), [f'{gcm}_{variant}'])
    concat_dset['GCM'] = (('GCM_variant'), [gcm])
    ssp_dset.append(concat_dset)
# Out:
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_DKRZ_MPI-ESM1-2-HR_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 9.18 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r6i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.88 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r34i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 8.08 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r37i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.98 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r10i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.76 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_MPI-M_MPI-ESM1-2-LR_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.87 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r24i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 8.18 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r3i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.58 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r36i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.77 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r10i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.67 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r27i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.67 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO-ARCCSS_ACCESS-CM2_ssp370_r4i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 10.91 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r16i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.57 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r9i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.47 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r2i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.57 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r40i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 8.49 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r1i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.98 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r7i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.78 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r30i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.78 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_AS-RCEC_TaiESM1_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.58 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r13i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.88 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_EC-Earth-Consortium_EC-Earth3-Veg_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 12.11 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_EC-Earth-Consortium_EC-Earth3_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 8.37 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CNRM-CERFACS_CNRM-CM6-1_ssp370_r1i1p1f2_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.96 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r15i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.97 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r11i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.85 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r19i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 16.73 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r7i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 8.09 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r23i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.97 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r8i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.77 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r14i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 8.89 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r12i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 8.08 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r5i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.88 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r5i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.28 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r10i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.78 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.66 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r39i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.88 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CMCC_CMCC-ESM2_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.88 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r9i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.77 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r4i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.48 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r31i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 8.18 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r8i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 6.76 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCR-IITM_IITM-ESM_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.16 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r32i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.57 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_MOHC_UKESM1-0-LL_ssp370_r1i1p1f2_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.38 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r22i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 9.19 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r5i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.67 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r4i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.16 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r33i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.28 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r26i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.77 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r6i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.58 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r3i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.57 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_NCC_NorESM2-LM_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 10.30 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r2i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.78 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r6i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.48 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 13.73 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_IPSL_IPSL-CM6A-LR_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.77 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_NCC_NorESM2-MM_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.38 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_EC-Earth-Consortium_EC-Earth3-Veg-LR_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.68 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_NASA-GISS_GISS-E2-1-G_ssp370_r1i1p1f2_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.78 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r7i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.48 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r20i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 8.99 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r2i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.98 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CMCC_CMCC-CM2-SR5_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.36 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_INM_INM-CM4-8_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.27 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r21i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.48 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r17i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.16 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r25i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.47 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r28i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.98 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_INM_INM-CM5-0_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.68 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r38i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.47 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r35i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.48 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r4i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.96 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r8i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.17 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r3i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.58 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r18i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 8.17 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r29i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.77 ss

# %%
concat_dset_future = xr.concat(ssp_dset, dim ="GCM_variant")

# %%
import matplotlib.pyplot as plt

# %%
concat_dset
# Out:
# <xarray.Dataset>
# Dimensions:               (GCM_variant: 1, season: 4, lat: 172, lon: 179, year: 65)
# Coordinates:
#   * lon                   (lon) float32 164.9 165.0 165.1 ... 183.7 183.9 184.0
#   * lat                   (lat) float32 -51.21 -51.11 -51.0 ... -32.97 -32.86
#     GCM                   (GCM_variant) <U13 'ACCESS-ESM1-5'
#     scenario              <U10 'historical'
#   * season                (season) object 'DJF' 'JJA' 'MAM' 'SON'
#   * year                  (year) int64 1950 1951 1952 1953 ... 2012 2013 2014
#   * GCM_variant           (GCM_variant) <U22 'ACCESS-ESM1-5_r2i1p1f1'
# Data variables:
#     seasonal_tasmax_hist  (GCM_variant, season, lat, lon) float64 284.7 ... 2...
#     TXx                   (GCM_variant, year, lat, lon) float64 287.6 ... 298.7

# %%
files_glob_tx = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_*historical*_day_NZ12km_NIWA-REMS_tasmax_v280125.nc')
#files_glob_pr = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/{ssp}/daily/pr/pr_ScenarioMIP_*{ssp}*_day_NZ12km_NIWA-REMS_pr_v280125.nc')
ssp_dset = []
for file in files_glob_tx:
    print(file)
    with ProgressBar():
        df = xr.open_dataset(file, chunks ={"time":5000}).load()
    seasonal_climo = df.sel(time = slice('1986','2005')).groupby('time.season').mean().rename({"tasmax":"seasonal_tasmax_hist"})
    rx1day = df.groupby('time.year').max().rename({"tasmax":"TXx"})
    concat_dset = xr.merge([seasonal_climo, rx1day])
    concat_dset = concat_dset.expand_dims({"GCM_variant":1})
    variant = file.split('/')[-1].split('_')[5]
    ssp = file.split('/')[-1].split('_')[4]
    gcm = file.split('/')[-1].split('_')[3]
    concat_dset['GCM_variant'] = (('GCM_variant'), [f'{gcm}_{variant}'])
    concat_dset['GCM'] = (('GCM_variant'), [gcm])
    ssp_dset.append(concat_dset)
concat_dset_hist = xr.concat(ssp_dset, dim ="GCM_variant")
# Out:
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r3i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 12.41 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CNRM-CERFACS_CNRM-CM6-1_historical_r1i1p1f2_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.56 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_EC-Earth-Consortium_EC-Earth3_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.86 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r35i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.86 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r24i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.96 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r12i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.65 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r30i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.66 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r10i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.40 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r31i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.67 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r6i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.82 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 12.02 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_INM_INM-CM5-0_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.56 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.65 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_NCC_NorESM2-LM_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.85 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r39i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.55 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_INM_INM-CM4-8_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.86 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r27i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.86 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r7i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 10.52 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r32i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.66 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r10i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 7.17 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_IPSL_IPSL-CM6A-LR_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.56 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_MPI-M_MPI-ESM1-2-HR_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.56 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r33i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.66 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r14i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.46 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r10i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.80 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r1i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.41 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r9i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.71 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_MOHC_UKESM1-0-LL_historical_r1i1p1f2_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.55 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r13i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.55 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r5i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.45 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r4i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 13.01 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r6i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.86 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r18i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.86 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCR-IITM_IITM-ESM_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.66 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r25i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.76 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r26i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.15 sms
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r22i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.55 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r7i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.50 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r9i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.66 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r23i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.76 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r16i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.86 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_MPI-M_MPI-ESM1-2-LR_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.56 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r38i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.55 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_EC-Earth-Consortium_EC-Earth3-Veg-LR_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.76 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r3i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.93 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_EC-Earth-Consortium_EC-Earth3-Veg_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.56 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r2i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.61 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r5i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.49 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r8i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.92 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r29i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.86 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r28i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 6.57 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_NCC_NorESM2-MM_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.85 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r2i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.51 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r8i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 10.29 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CMCC_CMCC-ESM2_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.76 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r21i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.55 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r4i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.60 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r5i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.81 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r36i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.36 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r19i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.35 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r40i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.26 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r15i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.35 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r34i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.46 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r37i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r4i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.15 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CCCma_CanESM5_historical_r6i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 11.12 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r8i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.35 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r20i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.15 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO-ARCCSS_ACCESS-CM2_historical_r4i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.15 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_NASA-GISS_GISS-E2-1-G_historical_r1i1p1f2_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.35 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r3i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.66 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CMCC_CMCC-CM2-SR5_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 6.57 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r7i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.66 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_AS-RCEC_TaiESM1_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 6.66 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r11i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.65 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r17i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.85 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/tasmax/tasmax_CMIP_CSIRO_ACCESS-ESM1-5_historical_r2i1p1f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc
# [########################################] | 100% Completed | 5.66 ss

# %%
Txx = xr.concat([concat_dset_hist.TXx, concat_dset_future.TXx], dim ="year").to_dataset()

# %%
concat_dset_future.rename({"seasonal_tasmax":"seasonal_tasmax_future"})
# Out:
# <xarray.Dataset>
# Dimensions:                 (year: 86, GCM_variant: 77, season: 4, lat: 172, lon: 179)
# Coordinates:
#   * year                    (year) int64 2015 2016 2017 2018 ... 2098 2099 2100
#   * lon                     (lon) float32 164.9 165.0 165.1 ... 183.9 184.0
#   * lat                     (lat) float32 -51.21 -51.11 -51.0 ... -32.97 -32.86
#     GCM                     (GCM_variant) <U16 'MPI-ESM1-2-HR' ... 'ACCESS-ES...
#     scenario                <U6 'ssp370'
#   * season                  (season) object 'DJF' 'JJA' 'MAM' 'SON'
#   * GCM_variant             (GCM_variant) <U25 'MPI-ESM1-2-HR_r1i1p1f1' ... '...
# Data variables:
#     seasonal_tasmax_future  (GCM_variant, season, lat, lon) float64 285.0 ......
#     TXx                     (GCM_variant, year, lat, lon) float64 287.1 ... 3...

# %%
merged_T = xr.merge([Txx, concat_dset_future.rename({"seasonal_tasmax":"seasonal_tasmax_future"}).seasonal_tasmax_future.drop({"scenario"}),
                     concat_dset_hist.seasonal_tasmax_hist.drop({"scenario"})])

# %%
merged_T
# Out:
# <xarray.Dataset>
# Dimensions:                 (GCM_variant: 77, year: 152, lon: 179, lat: 172, season: 4)
# Coordinates:
#   * GCM_variant             (GCM_variant) <U25 'ACCESS-CM2_r4i1p1f1' ... 'UKE...
#   * year                    (year) int64 1950 1951 1952 1953 ... 2098 2099 2100
#   * lon                     (lon) float32 164.9 165.0 165.1 ... 183.9 184.0
#   * lat                     (lat) float32 -51.21 -51.11 -51.0 ... -32.97 -32.86
#     GCM                     (GCM_variant) <U16 'ACCESS-CM2' ... 'UKESM1-0-LL'
#     scenario                (year) <U10 'historical' 'historical' ... 'ssp370'
#   * season                  (season) object 'DJF' 'JJA' 'MAM' 'SON'
# Data variables:
#     TXx                     (GCM_variant, year, lat, lon) float64 287.5 ... 3...
#     seasonal_tasmax_future  (GCM_variant, season, lat, lon) float64 285.3 ......
#     seasonal_tasmax_hist    (GCM_variant, season, lat, lon) float64 283.9 ......

# %%
files_glob_pr = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_*ssp370*_day_NZ12km_NIWA-REMS_pr_v280125.nc')
#files_glob_pr = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/{ssp}/daily/pr/pr_ScenarioMIP_*{ssp}*_day_NZ12km_NIWA-REMS_pr_v280125.nc')
ssp_dset = []
for file in files_glob_pr:
    print(file)
    with ProgressBar():
        df = xr.open_dataset(file, chunks ={"time":5000}).load()
    seasonal_climo = df.sel(time = slice('2080','2099')).groupby('time.season').mean().rename({"pr":"seasonal_pr_future"})
    rx1day = df.groupby('time.year').max().rename({"pr":"Rx1day"})
    concat_dset = xr.merge([seasonal_climo, rx1day])
    concat_dset = concat_dset.expand_dims({"GCM_variant":1})
    variant = file.split('/')[-1].split('_')[5]
    ssp = file.split('/')[-1].split('_')[4]
    gcm = file.split('/')[-1].split('_')[3]
    concat_dset['GCM_variant'] = (('GCM_variant'), [f'{gcm}_{variant}'])
    concat_dset['GCM'] = (('GCM_variant'), [gcm])
    ssp_dset.append(concat_dset)
concat_dset_pr = xr.concat(ssp_dset, dim ="GCM_variant")
# Out:
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r23i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.07 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CCCma_CanESM5_ssp370_r3i1p2f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.18 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_INM_INM-CM5-0_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.89 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r2i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.17 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r27i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.07 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r36i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.17 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_MPI-M_MPI-ESM1-2-LR_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.98 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r28i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.18 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r24i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.07 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r33i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.08 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_AS-RCEC_TaiESM1_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.08 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r20i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.87 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CMCC_CMCC-ESM2_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.98 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CCCR-IITM_IITM-ESM_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.88 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CCCma_CanESM5_ssp370_r8i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.18 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_EC-Earth-Consortium_EC-Earth3-Veg_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 8.69 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r32i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.07 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_NASA-GISS_GISS-E2-1-G_ssp370_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.98 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r29i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.78 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_DKRZ_MPI-ESM1-2-HR_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.67 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CCCma_CanESM5_ssp370_r7i1p2f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.97 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r18i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.29 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r13i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.97 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_IPSL_IPSL-CM6A-LR_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.96 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r25i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.08 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r9i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.37 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r21i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.98 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_NCC_NorESM2-MM_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.87 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CCCma_CanESM5_ssp370_r5i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.27 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CMCC_CMCC-CM2-SR5_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.98 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r15i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.87 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CCCma_CanESM5_ssp370_r9i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.27 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_MOHC_UKESM1-0-LL_ssp370_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.08 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.07 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r17i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 8.59 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r8i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.17 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CCCma_CanESM5_ssp370_r8i1p2f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.38 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CNRM-CERFACS_CNRM-CM6-1_ssp370_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.97 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r39i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.08 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp370_r35i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 7.06 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_EC-Earth-Consortium_EC-Earth3_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 6.97 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CCCma_CanESM5_ssp370_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [                                        ] | 0% Completed | 1.01 s ms
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
files_glob_pr = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_*historical*_day_NZ12km_NIWA-REMS_pr_v280125.nc')
#files_glob_pr = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/{ssp}/daily/pr/pr_ScenarioMIP_*{ssp}*_day_NZ12km_NIWA-REMS_pr_v280125.nc')
ssp_dset = []
for file in files_glob_pr:
    print(file)
    with ProgressBar():
        df = xr.open_dataset(file, chunks ={"time":5000}).load()
    seasonal_climo = df.sel(time = slice('1986','2005')).groupby('time.season').mean().rename({"pr":"seasonal_pr_hist"})
    rx1day = df.groupby('time.year').max().rename({"pr":"Rx1day"})
    concat_dset = xr.merge([seasonal_climo, rx1day])
    concat_dset = concat_dset.expand_dims({"GCM_variant":1})
    variant = file.split('/')[-1].split('_')[5]
    ssp = file.split('/')[-1].split('_')[4]
    gcm = file.split('/')[-1].split('_')[3]
    concat_dset['GCM_variant'] = (('GCM_variant'), [f'{gcm}_{variant}'])
    concat_dset['GCM'] = (('GCM_variant'), [gcm])
    ssp_dset.append(concat_dset)
concat_dset_pr_hist = xr.concat(ssp_dset, dim ="GCM_variant")
# Out:
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CCCma_CanESM5_historical_r10i1p2f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 11.52 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CCCma_CanESM5_historical_r6i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 11.63 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r34i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.66 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r33i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.44 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r19i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 4.85 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_INM_INM-CM4-8_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.46 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CCCma_CanESM5_historical_r7i1p2f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 11.01 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CMCC_CMCC-CM2-SR5_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 3.53 sms
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_EC-Earth-Consortium_EC-Earth3_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CCCma_CanESM5_historical_r8i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 12.11 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r8i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r9i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r16i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.56 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r4i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.35 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r13i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.16 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_NCC_NorESM2-MM_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO-ARCCSS_ACCESS-CM2_historical_r4i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 4.85 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r26i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r32i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.47 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CCCma_CanESM5_historical_r10i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 11.51 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r38i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r17i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.56 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r37i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.45 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r11i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.36 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r27i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r25i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r7i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.15 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r24i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.26 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_MOHC_UKESM1-0-LL_historical_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.05 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r30i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.36 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CCCma_CanESM5_historical_r1i1p2f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 11.41 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r6i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.26 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CCCma_CanESM5_historical_r4i1p2f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 11.91 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r29i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CNRM-CERFACS_CNRM-CM6-1_historical_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.55 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r23i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_MPI-M_MPI-ESM1-2-HR_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.35 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_MPI-M_MPI-ESM1-2-LR_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.55 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CMCC_CMCC-ESM2_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.17 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_EC-Earth-Consortium_EC-Earth3-Veg_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.45 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r36i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.26 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CSIRO_ACCESS-ESM1-5_historical_r3i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.25 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_INM_INM-CM5-0_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 5.66 ss
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CCCma_CanESM5_historical_r5i1p2f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [########################################] | 100% Completed | 11.72 s
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr/pr_CMIP_CCCma_CanESM5_historical_r4i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# [################################        ] | 80% Completed | 10.90 ss
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
rx1day = xr.concat([concat_dset_pr_hist.Rx1day, concat_dset_pr.Rx1day], dim ="year").to_dataset()

# %%
merged_P = xr.merge([rx1day , concat_dset_pr_hist.seasonal_pr_hist.drop({"scenario"}),
                     concat_dset_pr.seasonal_pr_future.drop({"scenario"})])

# %%
All_merged = xr.merge([merged_P, merged_T])

# %%
All_merged.to_netcdf(r'/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/NIWA-REMS_AI_P_T_indicators_final.nc')

# %%
All_merged = xr.open_dataset(r'/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/NIWA-REMS_AI_P_T_indicators_final.nc')

# %% [markdown]
# # Potential to make Nature Climate Change paper
# (a) Regional Climate Change signal (TXX vs CCAM), and then model uncertainty, vs internal variability uncertainty
# (b) Show the plots at different regions.
# All_merged_CCAM
