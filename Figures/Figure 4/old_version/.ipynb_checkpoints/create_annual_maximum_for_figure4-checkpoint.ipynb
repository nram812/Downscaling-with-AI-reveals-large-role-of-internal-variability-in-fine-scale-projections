# %%
import glob
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import seaborn as sns
from scipy.stats import linregress
from dask.diagnostics import ProgressBar
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /nesi/project/niwa00018/rampaln/envs/ml_env_v2/share/proj failed
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %% [markdown]
# # Need to find large ensemble for Precip and Temperature

# %%
canesm = ['CanESM5_r10i1p1f1', 'CanESM5_r10i1p2f1',
       'CanESM5_r1i1p1f1', 'CanESM5_r1i1p2f1', 'CanESM5_r2i1p1f1',
       'CanESM5_r2i1p2f1', 'CanESM5_r3i1p1f1', 'CanESM5_r3i1p2f1',
       'CanESM5_r4i1p1f1', 'CanESM5_r4i1p2f1', 'CanESM5_r5i1p1f1',
       'CanESM5_r5i1p2f1', 'CanESM5_r6i1p1f1', 'CanESM5_r6i1p2f1',
       'CanESM5_r7i1p1f1', 'CanESM5_r7i1p2f1', 'CanESM5_r8i1p1f1',
       'CanESM5_r8i1p2f1', 'CanESM5_r9i1p1f1']
accessesm1 = ['ACCESS-ESM1-5_r10i1p1f1',
       'ACCESS-ESM1-5_r11i1p1f1', 'ACCESS-ESM1-5_r12i1p1f1',
       'ACCESS-ESM1-5_r13i1p1f1', 'ACCESS-ESM1-5_r14i1p1f1',
       'ACCESS-ESM1-5_r15i1p1f1', 'ACCESS-ESM1-5_r16i1p1f1',
       'ACCESS-ESM1-5_r17i1p1f1', 'ACCESS-ESM1-5_r18i1p1f1',
       'ACCESS-ESM1-5_r19i1p1f1', 'ACCESS-ESM1-5_r1i1p1f1',
       'ACCESS-ESM1-5_r20i1p1f1', 'ACCESS-ESM1-5_r21i1p1f1',
       'ACCESS-ESM1-5_r22i1p1f1', 'ACCESS-ESM1-5_r23i1p1f1',
       'ACCESS-ESM1-5_r24i1p1f1', 'ACCESS-ESM1-5_r25i1p1f1',
       'ACCESS-ESM1-5_r26i1p1f1', 'ACCESS-ESM1-5_r27i1p1f1',
       'ACCESS-ESM1-5_r28i1p1f1', 'ACCESS-ESM1-5_r29i1p1f1',
       'ACCESS-ESM1-5_r2i1p1f1', 'ACCESS-ESM1-5_r30i1p1f1',
       'ACCESS-ESM1-5_r31i1p1f1', 'ACCESS-ESM1-5_r32i1p1f1',
       'ACCESS-ESM1-5_r33i1p1f1', 'ACCESS-ESM1-5_r34i1p1f1',
       'ACCESS-ESM1-5_r35i1p1f1', 'ACCESS-ESM1-5_r36i1p1f1',
       'ACCESS-ESM1-5_r37i1p1f1', 'ACCESS-ESM1-5_r38i1p1f1',
       'ACCESS-ESM1-5_r39i1p1f1', 'ACCESS-ESM1-5_r3i1p1f1',
       'ACCESS-ESM1-5_r40i1p1f1', 'ACCESS-ESM1-5_r4i1p1f1',
       'ACCESS-ESM1-5_r5i1p1f1', 'ACCESS-ESM1-5_r6i1p1f1',
       'ACCESS-ESM1-5_r7i1p1f1', 'ACCESS-ESM1-5_r8i1p1f1',
       'ACCESS-ESM1-5_r9i1p1f1']

list_of_gcms = ['CNRM-CM6-1_r1i1p1f2', 'UKESM1-0-LL_r1i1p1f2',
       'GISS-E2-1-G_r1i1p1f2', 'IITM-ESM_r1i1p1f1', 'CanESM5_r1i1p1f1',
       'INM-CM5-0_r1i1p1f1', 'INM-CM4-8_r1i1p1f1', 'TaiESM1_r1i1p1f1',
       'EC-Earth3-Veg-LR_r1i1p1f1', 'EC-Earth3_r1i1p1f1',
       'EC-Earth3-Veg_r1i1p1f1', 'CMCC-ESM2_r1i1p1f1', 'CMCC-CM2-SR5_r1i1p1f1',
       'ACCESS-ESM1-5_r1i1p1f1', 'ACCESS-CM2_r4i1p1f1', 'IPSL-CM6A-LR_r1i1p1f1',
       'NorESM2-LM_r1i1p1f1', 'NorESM2-MM_r1i1p1f1', 'MPI-ESM1-2-LR_r1i1p1f1',
       'MPI-ESM1-2-HR_r1i1p1f1']

# %%
# We need to use the historical and concatenate the future on here
# we also should use the "list_of_gcms" list here.

# %%
def get_list_of_files(varname = "tasmax", GCM_variant_list = list_of_gcms,  ssp = 'ssp370', base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public'):
    gcm = [GCM.split('_')[0] for GCM in GCM_variant_list]
    variant = [GCM.split('_')[1] for GCM in GCM_variant_list]
    if not varname == "pr":
        if ssp == 'historical':
            files_glob_tx = [glob.glob(f'{base_path}/{ssp}/daily/{varname}/{varname}_CMIP_*_{gcm[i]}_{ssp}_{variant[i]}_day_NZ12km_NIWA-REMS_{varname}_v??????.nc')[0] for i in range(len(gcm))]
        else:
            files_glob_tx = [glob.glob(f'{base_path}/{ssp}/daily/{varname}/{varname}_ScenarioMIP_*_{gcm[i]}_{ssp}_{variant[i]}_day_NZ12km_NIWA-REMS_{varname}_v??????.nc')[0] for i in range(len(gcm))]
    else:
        if ssp == 'historical':
            files_glob_tx = [glob.glob(f'{base_path}/{ssp}/daily/{varname}/{varname}_CMIP_*_{gcm[i]}_{ssp}_{variant[i]}_day_NZ12km_NIWA-REMS_v??????_pr.nc')[0] for i in range(len(gcm))]
        else:
            files_glob_tx = [glob.glob(f'{base_path}/{ssp}/daily/{varname}/{varname}_ScenarioMIP_*_{gcm[i]}_{ssp}_{variant[i]}_day_NZ12km_NIWA-REMS_v??????_pr.nc')[0] for i in range(len(gcm))]
    return files_glob_tx

# %%
z1 = np.random.rand(0,2,100)

# %%
def compute_future_reference(file, txx_reference, seasonal_reference, historical_dset, varname ="tasmax"):
    with ProgressBar():
        with xr.open_dataset(file, chunks={'time': 300}) as ds:
            ds = ds.sel(time=slice("2015", None))
            ds = xr.concat([historical_dset, ds[varname]], dim ="time")
            tasmax = ds

            # Compute TXx more efficiently using Dask
            if varname == "pr":
                txx_future = 100* (tasmax.groupby("time.year").max() - txx_reference)/txx_reference
            else:
                
                txx_future = tasmax.groupby("time.year").max() - txx_reference

            # Compute seasonal mean for February (DJF mid-point)
            seasonal = tasmax.resample(time="1MS").mean()
            seasonal = seasonal.rolling(time=3).mean()
            if varname == "pr":
                seasonal = 100 * (seasonal.sel(time=seasonal.time.dt.month == 2) - seasonal_reference)/seasonal_reference
            else:
                
                seasonal = seasonal.sel(time=seasonal.time.dt.month == 2) - seasonal_reference

            return txx_future.compute(), seasonal.compute()

# %%
ssps = ['ssp126','ssp245', 'ssp370', 'ssp585']
# first get the historical
historical_files = get_list_of_files(varname = "tasmax", GCM_variant_list = list_of_gcms,  ssp = "historical", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
ssp126_files = get_list_of_files(varname = "tasmax", GCM_variant_list = list_of_gcms,  ssp = "ssp126", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
ssp245_files = get_list_of_files(varname = "tasmax", GCM_variant_list = list_of_gcms,  ssp = "ssp245", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
ssp370_files = get_list_of_files(varname = "tasmax", GCM_variant_list = list_of_gcms,  ssp = "ssp370", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
ssp585_files = get_list_of_files(varname = "tasmax", GCM_variant_list = list_of_gcms,  ssp = "ssp585", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
seasonal_dsets = []
txx_dsets = []
for i, file in enumerate(historical_files):
    print(file.split('/')[-1].split('_')[3], ssp126_files[i].split('/')[-1].split('_')[3], ssp245_files[i].split('/')[-1].split('_')[3],ssp370_files[i].split('/')[-1].split('_')[3] ,ssp585_files[i].split('/')[-1].split('_')[3])
    historical_tx = xr.open_dataset(historical_files[i]).sel(time = slice("1995","2014")).tasmax
    # first compute a climatological reference
    txx_reference = historical_tx.groupby('time.year').max().mean("year") # a reference climatology
    seasonal_reference = historical_tx.groupby('time.season').mean().sel(season = 'DJF')
    
    txx_ssp126, seasonal_ssp126 = compute_future_reference(ssp126_files[i], txx_reference, seasonal_reference, historical_tx)
    txx_ssp245, seasonal_ssp245 = compute_future_reference(ssp245_files[i], txx_reference, seasonal_reference, historical_tx)
    txx_ssp370, seasonal_ssp370 = compute_future_reference(ssp370_files[i], txx_reference, seasonal_reference, historical_tx)
    txx_ssp585, seasonal_ssp585 = compute_future_reference(ssp585_files[i], txx_reference, seasonal_reference, historical_tx)
    
    txx_dset = xr.concat([txx_ssp126, txx_ssp245, txx_ssp370, txx_ssp585], dim = "ssp")
    txx_dset['ssp'] = (('ssp'), ssps)
    seasonal_dset = xr.concat([seasonal_ssp126, seasonal_ssp245, seasonal_ssp370, seasonal_ssp585], dim = "ssp")
    seasonal_dset['ssp'] = (('ssp'), ssps)
    txx_dset = txx_dset.expand_dims({"GCM":1})
    seasonal_dset = seasonal_dset.expand_dims({"GCM":1})

    gcm = ssp126_files[i].split('/')[-1].split('_')[3]
    txx_dset['GCM'] = (('GCM'), [gcm])
    seasonal_dset['GCM'] = (('GCM'), [gcm])
    txx_dsets.append(txx_dset)
    seasonal_dsets.append(seasonal_dset)
# Out:
# CNRM-CM6-1 CNRM-CM6-1 CNRM-CM6-1 CNRM-CM6-1 CNRM-CM6-1
# [########################################] | 100% Completed | 13.73 ss
# [########################################] | 100% Completed | 8.87 sms
# [########################################] | 100% Completed | 12.26 ss
# [########################################] | 100% Completed | 9.24 sms
# [########################################] | 100% Completed | 11.47 ss
# [########################################] | 100% Completed | 8.87 sms
# [########################################] | 100% Completed | 12.59 ss
# [########################################] | 100% Completed | 9.03 sms
# UKESM1-0-LL UKESM1-0-LL UKESM1-0-LL UKESM1-0-LL UKESM1-0-LL
# [########################################] | 100% Completed | 12.89 ss
# [########################################] | 100% Completed | 8.96 sms
# [########################################] | 100% Completed | 15.17 ss
# [########################################] | 100% Completed | 11.94 ss
# [########################################] | 100% Completed | 14.96 ss
# [########################################] | 100% Completed | 9.48 sms
# [########################################] | 100% Completed | 13.32 ss
# [########################################] | 100% Completed | 13.64 ss
# GISS-E2-1-G GISS-E2-1-G GISS-E2-1-G GISS-E2-1-G GISS-E2-1-G
# [########################################] | 100% Completed | 19.09 s
# [########################################] | 100% Completed | 18.69 ss
# [########################################] | 100% Completed | 24.55 s
# [########################################] | 100% Completed | 18.26 ss
# [########################################] | 100% Completed | 21.39 ss
# [########################################] | 100% Completed | 17.09 ss
# [########################################] | 100% Completed | 24.56 ss
# [########################################] | 100% Completed | 17.76 ss
# IITM-ESM IITM-ESM IITM-ESM IITM-ESM IITM-ESM
# [########################################] | 100% Completed | 22.56 s
# [########################################] | 100% Completed | 13.94 ss
# [########################################] | 100% Completed | 21.61 s
# [########################################] | 100% Completed | 13.34 ss
# [########################################] | 100% Completed | 20.22 ss
# [########################################] | 100% Completed | 17.75 ss
# [########################################] | 100% Completed | 17.02 ss
# [########################################] | 100% Completed | 13.78 ss
# CanESM5 CanESM5 CanESM5 CanESM5 CanESM5
# [########################################] | 100% Completed | 13.67 ss
# [########################################] | 100% Completed | 10.33 ss
# [########################################] | 100% Completed | 12.06 ss
# [########################################] | 100% Completed | 9.62 sms
# [########################################] | 100% Completed | 12.28 ss
# [########################################] | 100% Completed | 9.39 sms
# [########################################] | 100% Completed | 12.60 ss
# [########################################] | 100% Completed | 10.45 ss
# INM-CM5-0 INM-CM5-0 INM-CM5-0 INM-CM5-0 INM-CM5-0
# [########################################] | 100% Completed | 11.94 ss
# [########################################] | 100% Completed | 9.54 sms
# [########################################] | 100% Completed | 12.34 ss
# [########################################] | 100% Completed | 9.95 sms
# [########################################] | 100% Completed | 13.49 ss
# [########################################] | 100% Completed | 10.66 ss
# [########################################] | 100% Completed | 13.07 ss
# [########################################] | 100% Completed | 9.05 sms
# INM-CM4-8 INM-CM4-8 INM-CM4-8 INM-CM4-8 INM-CM4-8
# [########################################] | 100% Completed | 17.97 ss
# [########################################] | 100% Completed | 14.07 ss
# [########################################] | 100% Completed | 18.64 ss
# [########################################] | 100% Completed | 14.03 ss
# [########################################] | 100% Completed | 15.13 ss
# [########################################] | 100% Completed | 11.55 ss
# [########################################] | 100% Completed | 15.56 ss
# [########################################] | 100% Completed | 14.45 ss
# TaiESM1 TaiESM1 TaiESM1 TaiESM1 TaiESM1
# [########################################] | 100% Completed | 15.64 ss
# [########################################] | 100% Completed | 11.26 ss
# [########################################] | 100% Completed | 19.53 ss
# [########################################] | 100% Completed | 13.02 ss
# [########################################] | 100% Completed | 16.52 ss
# [########################################] | 100% Completed | 11.28 ss
# [########################################] | 100% Completed | 14.10 ss
# [########################################] | 100% Completed | 10.45 ss
# EC-Earth3-Veg-LR EC-Earth3-Veg-LR EC-Earth3-Veg-LR EC-Earth3-Veg-LR EC-Earth3-Veg-LR
# [########################################] | 100% Completed | 14.59 ss
# [########################################] | 100% Completed | 12.21 ss
# [########################################] | 100% Completed | 13.42 ss
# [########################################] | 100% Completed | 13.07 ss
# [########################################] | 100% Completed | 16.41 ss
# [########################################] | 100% Completed | 12.26 ss
# [########################################] | 100% Completed | 15.23 ss
# [########################################] | 100% Completed | 11.36 ss
# EC-Earth3 EC-Earth3 EC-Earth3 EC-Earth3 EC-Earth3
# [########################################] | 100% Completed | 17.45 ss
# [########################################] | 100% Completed | 10.29 ss
# [########################################] | 100% Completed | 16.11 ss
# [########################################] | 100% Completed | 8.87 sms
# [########################################] | 100% Completed | 13.80 ss
# [########################################] | 100% Completed | 8.84 sms
# [########################################] | 100% Completed | 15.29 s
# [########################################] | 100% Completed | 9.82 sms
# EC-Earth3-Veg EC-Earth3-Veg EC-Earth3-Veg EC-Earth3-Veg EC-Earth3-Veg
# [########################################] | 100% Completed | 13.46 ss
# [########################################] | 100% Completed | 11.56 ss
# [########################################] | 100% Completed | 12.18 ss
# [########################################] | 100% Completed | 15.86 ss
# [########################################] | 100% Completed | 13.41 ss
# [########################################] | 100% Completed | 13.66 ss
# [########################################] | 100% Completed | 18.55 ss
# [########################################] | 100% Completed | 13.97 ss
# CMCC-ESM2 CMCC-ESM2 CMCC-ESM2 CMCC-ESM2 CMCC-ESM2
# [########################################] | 100% Completed | 15.70 ss
# [########################################] | 100% Completed | 15.60 ss
# [########################################] | 100% Completed | 17.76 ss
# [########################################] | 100% Completed | 13.22 ss
# [########################################] | 100% Completed | 13.59 ss
# [########################################] | 100% Completed | 9.28 sms
# [########################################] | 100% Completed | 10.57 ss
# [########################################] | 100% Completed | 7.44 sms
# CMCC-CM2-SR5 CMCC-CM2-SR5 CMCC-CM2-SR5 CMCC-CM2-SR5 CMCC-CM2-SR5
# [########################################] | 100% Completed | 11.81 ss
# [########################################] | 100% Completed | 9.25 sms
# [########################################] | 100% Completed | 11.49 ss
# [########################################] | 100% Completed | 9.00 sms
# [########################################] | 100% Completed | 11.28 ss
# [########################################] | 100% Completed | 8.72 sms
# [########################################] | 100% Completed | 12.29 ss
# [########################################] | 100% Completed | 9.27 sms
# ACCESS-ESM1-5 ACCESS-ESM1-5 ACCESS-ESM1-5 ACCESS-ESM1-5 ACCESS-ESM1-5
# [########################################] | 100% Completed | 12.14 ss
# [########################################] | 100% Completed | 9.33 sms
# [########################################] | 100% Completed | 11.57 ss
# [########################################] | 100% Completed | 8.52 sms
# [########################################] | 100% Completed | 11.55 ss
# [########################################] | 100% Completed | 8.91 sms
# [########################################] | 100% Completed | 11.99 ss
# [########################################] | 100% Completed | 8.26 sms
# ACCESS-CM2 ACCESS-CM2 ACCESS-CM2 ACCESS-CM2 ACCESS-CM2
# [########################################] | 100% Completed | 11.23 ss
# [########################################] | 100% Completed | 8.79 sms
# [########################################] | 100% Completed | 11.47 ss
# [########################################] | 100% Completed | 8.44 sms
# [########################################] | 100% Completed | 10.96 ss
# [########################################] | 100% Completed | 8.97 sms
# [########################################] | 100% Completed | 11.15 ss
# [########################################] | 100% Completed | 8.92 sms
# IPSL-CM6A-LR IPSL-CM6A-LR IPSL-CM6A-LR IPSL-CM6A-LR IPSL-CM6A-LR
# [########################################] | 100% Completed | 12.29 ss
# [########################################] | 100% Completed | 9.32 sms
# [########################################] | 100% Completed | 12.44 ss
# [########################################] | 100% Completed | 8.89 sms
# [########################################] | 100% Completed | 11.95 ss
# [########################################] | 100% Completed | 8.54 sms
# [########################################] | 100% Completed | 12.47 ss
# [########################################] | 100% Completed | 9.75 sms
# NorESM2-LM NorESM2-LM NorESM2-LM NorESM2-LM NorESM2-LM
# [########################################] | 100% Completed | 17.93 ss
# [########################################] | 100% Completed | 12.34 ss
# [########################################] | 100% Completed | 12.48 ss
# [########################################] | 100% Completed | 9.22 sms
# [########################################] | 100% Completed | 12.66 ss
# [########################################] | 100% Completed | 8.72 sms
# [########################################] | 100% Completed | 12.57 ss
# [########################################] | 100% Completed | 10.53 ss
# NorESM2-MM NorESM2-MM NorESM2-MM NorESM2-MM NorESM2-MM
# [########################################] | 100% Completed | 13.17 ss
# [########################################] | 100% Completed | 9.68 sms
# [########################################] | 100% Completed | 12.28 ss
# [########################################] | 100% Completed | 8.60 sms
# [########################################] | 100% Completed | 12.76 ss
# [########################################] | 100% Completed | 9.22 sms
# [########################################] | 100% Completed | 12.07 ss
# [########################################] | 100% Completed | 8.41 sms
# MPI-ESM1-2-LR MPI-ESM1-2-LR MPI-ESM1-2-LR MPI-ESM1-2-LR MPI-ESM1-2-LR
# [########################################] | 100% Completed | 12.84 ss
# [########################################] | 100% Completed | 9.23 sms
# [########################################] | 100% Completed | 12.61 ss
# [########################################] | 100% Completed | 9.23 sms
# [########################################] | 100% Completed | 10.99 ss
# [########################################] | 100% Completed | 8.87 sms
# [########################################] | 100% Completed | 11.97 ss
# [########################################] | 100% Completed | 8.60 sms
# MPI-ESM1-2-HR MPI-ESM1-2-HR MPI-ESM1-2-HR MPI-ESM1-2-HR MPI-ESM1-2-HR
# [########################################] | 100% Completed | 11.86 ss
# [########################################] | 100% Completed | 7.81 sms
# [########################################] | 100% Completed | 10.94 ss
# [########################################] | 100% Completed | 7.81 sms
# [########################################] | 100% Completed | 10.97 ss
# [########################################] | 100% Completed | 8.72 sms
# [########################################] | 100% Completed | 11.07 ss
# [########################################] | 100% Completed | 8.32 sms

# %%
new_dsets = []
for dset in seasonal_dsets:
    dset['time'] = pd.to_datetime(dset.time.dt.strftime("%Y-%m-%d"))
    new_dsets.append(dset)

DJF_mme = xr.concat(new_dsets, dim ="GCM").to_dataset(name = 'DJF_MME')
TXX_mme = xr.concat(txx_dsets, dim ="GCM").to_dataset(name = 'TXX_MME')

# %%
merged_dset_TXX_DJF = xr.merge([TXX_mme, DJF_mme])
merged_dset_TXX_DJF.to_netcdf('/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/internal_variability_data/Multi_Model_Decomposition_tasmax_v250425.nc')

# %%
ssps = ['ssp126','ssp245', 'ssp370', 'ssp585']
# first get the historical
historical_files = get_list_of_files(varname = "pr", GCM_variant_list = list_of_gcms,  ssp = "historical", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
ssp126_files = get_list_of_files(varname = "pr", GCM_variant_list = list_of_gcms,  ssp = "ssp126", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
ssp245_files = get_list_of_files(varname = "pr", GCM_variant_list = list_of_gcms,  ssp = "ssp245", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
ssp370_files = get_list_of_files(varname = "pr", GCM_variant_list = list_of_gcms,  ssp = "ssp370", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
ssp585_files = get_list_of_files(varname = "pr", GCM_variant_list = list_of_gcms,  ssp = "ssp585", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
seasonal_dsets_pr = []
rx1day_dsets_pr = []
for i, file in enumerate(historical_files):
    print(file.split('/')[-1].split('_')[3], ssp126_files[i].split('/')[-1].split('_')[3], ssp245_files[i].split('/')[-1].split('_')[3],ssp370_files[i].split('/')[-1].split('_')[3] ,ssp585_files[i].split('/')[-1].split('_')[3])
    historical_tx = xr.open_dataset(historical_files[i]).sel(time = slice("1995","2014")).pr
    # first compute a climatological reference
    txx_reference = historical_tx.groupby('time.year').max().mean("year") # a reference climatology
    seasonal_reference = historical_tx.groupby('time.season').mean().sel(season = 'DJF')
    
    txx_ssp126, seasonal_ssp126 = compute_future_reference(ssp126_files[i], txx_reference, seasonal_reference,historical_tx,  varname ="pr")
    txx_ssp245, seasonal_ssp245 = compute_future_reference(ssp245_files[i], txx_reference, seasonal_reference,historical_tx, varname ="pr")
    txx_ssp370, seasonal_ssp370 = compute_future_reference(ssp370_files[i], txx_reference, seasonal_reference, historical_tx, varname ="pr")
    txx_ssp585, seasonal_ssp585 = compute_future_reference(ssp585_files[i], txx_reference, seasonal_reference, historical_tx, varname ="pr")
    
    txx_dset = xr.concat([txx_ssp126, txx_ssp245, txx_ssp370, txx_ssp585], dim = "ssp")
    txx_dset['ssp'] = (('ssp'), ssps)
    seasonal_dset = xr.concat([seasonal_ssp126, seasonal_ssp245, seasonal_ssp370, seasonal_ssp585], dim = "ssp")
    seasonal_dset['ssp'] = (('ssp'), ssps)
    txx_dset = txx_dset.expand_dims({"GCM":1})
    seasonal_dset = seasonal_dset.expand_dims({"GCM":1})

    gcm = ssp126_files[i].split('/')[-1].split('_')[3]
    txx_dset['GCM'] = (('GCM'), [gcm])
    seasonal_dset['GCM'] = (('GCM'), [gcm])
    rx1day_dsets_pr.append(txx_dset)
    seasonal_dsets_pr.append(seasonal_dset)
# Out:
# CNRM-CM6-1 CNRM-CM6-1 CNRM-CM6-1 CNRM-CM6-1 CNRM-CM6-1
# [########################################] | 100% Completed | 12.20 ss
# [########################################] | 100% Completed | 9.76 sms
# [########################################] | 100% Completed | 11.23 ss
# [########################################] | 100% Completed | 8.79 sms
# [########################################] | 100% Completed | 12.65 ss
# [########################################] | 100% Completed | 9.34 sms
# [########################################] | 100% Completed | 11.99 ss
# [########################################] | 100% Completed | 9.35 sms
# UKESM1-0-LL UKESM1-0-LL UKESM1-0-LL UKESM1-0-LL UKESM1-0-LL
# [########################################] | 100% Completed | 13.01 ss
# [########################################] | 100% Completed | 9.05 sms
# [########################################] | 100% Completed | 12.93 ss
# [########################################] | 100% Completed | 10.14 ss
# [########################################] | 100% Completed | 12.93 ss
# [########################################] | 100% Completed | 10.59 ss
# [########################################] | 100% Completed | 13.58 ss
# [########################################] | 100% Completed | 9.68 sms
# GISS-E2-1-G GISS-E2-1-G GISS-E2-1-G GISS-E2-1-G GISS-E2-1-G
# [########################################] | 100% Completed | 12.69 ss
# [########################################] | 100% Completed | 10.20 ss
# [########################################] | 100% Completed | 13.73 ss
# [########################################] | 100% Completed | 9.47 sms
# [########################################] | 100% Completed | 13.36 ss
# [########################################] | 100% Completed | 10.53 ss
# [########################################] | 100% Completed | 12.66 ss
# [########################################] | 100% Completed | 10.45 ss
# IITM-ESM IITM-ESM IITM-ESM IITM-ESM IITM-ESM
# [########################################] | 100% Completed | 12.99 ss
# [########################################] | 100% Completed | 9.53 sms
# [########################################] | 100% Completed | 12.89 s
# [########################################] | 100% Completed | 9.93 sms
# [########################################] | 100% Completed | 11.51 ss
# [########################################] | 100% Completed | 9.54 sms
# [########################################] | 100% Completed | 13.45 ss
# [########################################] | 100% Completed | 10.77 ss
# CanESM5 CanESM5 CanESM5 CanESM5 CanESM5
# [########################################] | 100% Completed | 12.47 ss
# [########################################] | 100% Completed | 10.56 ss
# [########################################] | 100% Completed | 13.06 ss
# [########################################] | 100% Completed | 10.04 ss
# [########################################] | 100% Completed | 12.20 ss
# [########################################] | 100% Completed | 9.78 sms
# [########################################] | 100% Completed | 14.84 ss
# [########################################] | 100% Completed | 10.27 ss
# INM-CM5-0 INM-CM5-0 INM-CM5-0 INM-CM5-0 INM-CM5-0
# [########################################] | 100% Completed | 13.34 ss
# [########################################] | 100% Completed | 11.44 ss
# [########################################] | 100% Completed | 14.75 ss
# [########################################] | 100% Completed | 9.49 sms
# [########################################] | 100% Completed | 13.34 ss
# [########################################] | 100% Completed | 10.30 ss
# [########################################] | 100% Completed | 14.13 ss
# [########################################] | 100% Completed | 12.48 ss
# INM-CM4-8 INM-CM4-8 INM-CM4-8 INM-CM4-8 INM-CM4-8
# [########################################] | 100% Completed | 13.75 ss
# [########################################] | 100% Completed | 10.53 ss
# [########################################] | 100% Completed | 14.60 ss
# [########################################] | 100% Completed | 10.28 ss
# [########################################] | 100% Completed | 12.10 ss
# [########################################] | 100% Completed | 10.06 ss
# [########################################] | 100% Completed | 14.93 ss
# [########################################] | 100% Completed | 12.93 ss
# TaiESM1 TaiESM1 TaiESM1 TaiESM1 TaiESM1
# [########################################] | 100% Completed | 20.07 ss
# [########################################] | 100% Completed | 15.21 ss
# [########################################] | 100% Completed | 25.95 s
# [########################################] | 100% Completed | 17.22 ss
# [########################################] | 100% Completed | 25.52 ss
# [########################################] | 100% Completed | 13.67 ss
# [########################################] | 100% Completed | 21.19 ss
# [########################################] | 100% Completed | 16.04 ss
# EC-Earth3-Veg-LR EC-Earth3-Veg-LR EC-Earth3-Veg-LR EC-Earth3-Veg-LR EC-Earth3-Veg-LR
# [########################################] | 100% Completed | 22.09 ss
# [########################################] | 100% Completed | 16.60 ss
# [########################################] | 100% Completed | 22.11 s
# [########################################] | 100% Completed | 21.07 ss
# [########################################] | 100% Completed | 24.22 ss
# [########################################] | 100% Completed | 16.14 ss
# [########################################] | 100% Completed | 21.79 ss
# [########################################] | 100% Completed | 15.31 ss
# EC-Earth3 EC-Earth3 EC-Earth3 EC-Earth3 EC-Earth3
# [########################################] | 100% Completed | 16.59 ss
# [########################################] | 100% Completed | 13.28 ss
# [########################################] | 100% Completed | 15.82 ss
# [########################################] | 100% Completed | 10.56 ss
# [########################################] | 100% Completed | 13.57 ss
# [########################################] | 100% Completed | 10.56 ss
# [########################################] | 100% Completed | 13.75 ss
# [########################################] | 100% Completed | 10.35 ss
# EC-Earth3-Veg EC-Earth3-Veg EC-Earth3-Veg EC-Earth3-Veg EC-Earth3-Veg
# [########################################] | 100% Completed | 13.54 ss
# [########################################] | 100% Completed | 11.22 ss
# [########################################] | 100% Completed | 14.45 ss
# [########################################] | 100% Completed | 12.29 ss
# [########################################] | 100% Completed | 14.12 ss
# [########################################] | 100% Completed | 11.39 ss
# [########################################] | 100% Completed | 15.18 ss
# [########################################] | 100% Completed | 12.11 ss
# CMCC-ESM2 CMCC-ESM2 CMCC-ESM2 CMCC-ESM2 CMCC-ESM2
# [########################################] | 100% Completed | 18.58 ss
# [########################################] | 100% Completed | 15.71 ss
# [########################################] | 100% Completed | 16.75 ss
# [########################################] | 100% Completed | 14.22 ss
# [########################################] | 100% Completed | 14.94 ss
# [########################################] | 100% Completed | 16.41 ss
# [########################################] | 100% Completed | 17.30 ss
# [########################################] | 100% Completed | 15.09 ss
# CMCC-CM2-SR5 CMCC-CM2-SR5 CMCC-CM2-SR5 CMCC-CM2-SR5 CMCC-CM2-SR5
# [########################################] | 100% Completed | 18.61 ss
# [########################################] | 100% Completed | 11.09 ss
# [########################################] | 100% Completed | 18.64 ss
# [########################################] | 100% Completed | 13.49 ss
# [########################################] | 100% Completed | 16.58 ss
# [########################################] | 100% Completed | 15.79 ss
# [########################################] | 100% Completed | 16.79 ss
# [########################################] | 100% Completed | 13.59 ss
# ACCESS-ESM1-5 ACCESS-ESM1-5 ACCESS-ESM1-5 ACCESS-ESM1-5 ACCESS-ESM1-5
# [########################################] | 100% Completed | 17.64 ss
# [########################################] | 100% Completed | 14.51 ss
# [########################################] | 100% Completed | 14.92 s
# [########################################] | 100% Completed | 17.31 ss
# [########################################] | 100% Completed | 14.62 ss
# [########################################] | 100% Completed | 16.54 ss
# [########################################] | 100% Completed | 19.67 ss
# [########################################] | 100% Completed | 11.24 ss
# ACCESS-CM2 ACCESS-CM2 ACCESS-CM2 ACCESS-CM2 ACCESS-CM2
# [########################################] | 100% Completed | 14.46 ss
# [########################################] | 100% Completed | 12.38 ss
# [########################################] | 100% Completed | 14.23 ss
# [########################################] | 100% Completed | 12.99 ss
# [########################################] | 100% Completed | 18.03 ss
# [########################################] | 100% Completed | 14.10 ss
# [########################################] | 100% Completed | 19.12 ss
# [########################################] | 100% Completed | 11.57 ss
# IPSL-CM6A-LR IPSL-CM6A-LR IPSL-CM6A-LR IPSL-CM6A-LR IPSL-CM6A-LR
# [########################################] | 100% Completed | 16.01 ss
# [########################################] | 100% Completed | 9.74 sms
# [########################################] | 100% Completed | 17.14 ss
# [########################################] | 100% Completed | 16.92 ss
# [########################################] | 100% Completed | 13.93 ss
# [########################################] | 100% Completed | 9.08 sms
# [########################################] | 100% Completed | 13.91 ss
# [########################################] | 100% Completed | 10.64 ss
# NorESM2-LM NorESM2-LM NorESM2-LM NorESM2-LM NorESM2-LM
# [########################################] | 100% Completed | 17.72 ss
# [########################################] | 100% Completed | 13.08 ss
# [########################################] | 100% Completed | 12.39 ss
# [########################################] | 100% Completed | 9.56 sms
# [########################################] | 100% Completed | 13.10 s
# [########################################] | 100% Completed | 9.04 sms
# [########################################] | 100% Completed | 13.08 ss
# [########################################] | 100% Completed | 9.86 sms
# NorESM2-MM NorESM2-MM NorESM2-MM NorESM2-MM NorESM2-MM
# [########################################] | 100% Completed | 12.08 ss
# [########################################] | 100% Completed | 9.42 sms
# [########################################] | 100% Completed | 13.97 s
# [########################################] | 100% Completed | 9.52 sms
# [########################################] | 100% Completed | 11.66 ss
# [########################################] | 100% Completed | 9.87 sms
# [########################################] | 100% Completed | 13.26 ss
# [########################################] | 100% Completed | 10.24 ss
# MPI-ESM1-2-LR MPI-ESM1-2-LR MPI-ESM1-2-LR MPI-ESM1-2-LR MPI-ESM1-2-LR
# [########################################] | 100% Completed | 11.86 ss
# [########################################] | 100% Completed | 8.96 sms
# [########################################] | 100% Completed | 12.98 ss
# [########################################] | 100% Completed | 9.52 sms
# [########################################] | 100% Completed | 12.55 ss
# [########################################] | 100% Completed | 8.96 sms
# [########################################] | 100% Completed | 11.45 ss
# [########################################] | 100% Completed | 8.93 sms
# MPI-ESM1-2-HR MPI-ESM1-2-HR MPI-ESM1-2-HR MPI-ESM1-2-HR MPI-ESM1-2-HR
# [########################################] | 100% Completed | 12.17 ss
# [########################################] | 100% Completed | 9.73 sms
# [########################################] | 100% Completed | 14.83 ss
# [########################################] | 100% Completed | 11.05 ss
# [########################################] | 100% Completed | 12.42 ss
# [########################################] | 100% Completed | 11.07 ss
# [########################################] | 100% Completed | 12.58 ss
# [########################################] | 100% Completed | 9.25 sms

# %%
Rx1day_mme_pr = xr.concat(rx1day_dsets_pr, dim ="GCM").to_dataset(name = 'Rx1day_MME')

new_dsets = []
for dset in seasonal_dsets_pr:
    dset['time'] = pd.to_datetime(dset.time.dt.strftime("%Y-%m-%d"))
    new_dsets.append(dset)

DJF_mme_pr= xr.concat(new_dsets, dim ="GCM").to_dataset(name = 'DJF_MME_pr')

#DJF_mme_pr = xr.concat(seasonal_dsets_pr, dim ="GCM").to_dataset(name = 'DJF_MME')
merged_dset_RX1DAY_DJF_pr = xr.merge([Rx1day_mme_pr , DJF_mme_pr])
merged_dset_RX1DAY_DJF_pr.to_netcdf('/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/internal_variability_data/Multi_Model_Decomposition_pr_v250425_percentage.nc')

# %%
ssps = ['ssp370']
# first get the historical
historical_files = get_list_of_files(varname = "tasmax", GCM_variant_list = accessesm1 + canesm,  ssp = "historical", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
ssp370_files = get_list_of_files(varname = "tasmax", GCM_variant_list = accessesm1 + canesm,  ssp = "ssp370", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
print(len(historical_files))
seasonal_dsets_iv = []
txx_dsets_iv = []
for i, file in enumerate(historical_files):
    historical_tx = xr.open_dataset(historical_files[i]).sel(time = slice("1995","2014")).tasmax
    # first compute a climatological reference
    txx_reference = historical_tx.groupby('time.year').max().mean("year") # a reference climatology
    seasonal_reference = historical_tx.groupby('time.season').mean().sel(season = 'DJF')
    txx_ssp370, seasonal_ssp370 = compute_future_reference(ssp370_files[i], txx_reference, seasonal_reference, historical_tx)
    
    # this is the large ensemble code
    variant = file.split('/')[-1].split('_')[5]
    gcm = ssp370_files[i].split('/')[-1].split('_')[3]
    
    
    txx_dset = txx_ssp370.expand_dims({"GCM_variant":1})
    seasonal_dset = seasonal_ssp370.expand_dims({"GCM_variant":1})
    print(f'{gcm}_{variant}')
    
    txx_dset['GCM_variant'] = (('GCM_variant'), [f'{gcm}_{variant}'])
    txx_dset['GCM'] = (('GCM_variant'), [f'{gcm}'])
    seasonal_dset['GCM_variant'] = (('GCM_variant'), [f'{gcm}_{variant}'])
    seasonal_dset['GCM'] = (('GCM_variant'), [f'{gcm}'])
    txx_dsets_iv.append(txx_dset)
    seasonal_dsets_iv.append(seasonal_dset)
# Out:
# 59
# [########################################] | 100% Completed | 12.09 ss
# [########################################] | 100% Completed | 9.64 sms
# ACCESS-ESM1-5_r10i1p1f1
# [########################################] | 100% Completed | 12.39 ss
# [########################################] | 100% Completed | 8.82 sms
# ACCESS-ESM1-5_r11i1p1f1
# [########################################] | 100% Completed | 12.61 ss
# [########################################] | 100% Completed | 9.38 sms
# ACCESS-ESM1-5_r12i1p1f1
# [########################################] | 100% Completed | 11.30 ss
# [########################################] | 100% Completed | 8.67 sms
# ACCESS-ESM1-5_r13i1p1f1
# [########################################] | 100% Completed | 11.35 ss
# [########################################] | 100% Completed | 9.18 sms
# ACCESS-ESM1-5_r14i1p1f1
# [########################################] | 100% Completed | 11.19 ss
# [########################################] | 100% Completed | 8.11 sms
# ACCESS-ESM1-5_r15i1p1f1
# [########################################] | 100% Completed | 11.35 ss
# [########################################] | 100% Completed | 8.98 sms
# ACCESS-ESM1-5_r16i1p1f1
# [########################################] | 100% Completed | 11.99 ss
# [########################################] | 100% Completed | 8.84 sms
# ACCESS-ESM1-5_r17i1p1f1
# [########################################] | 100% Completed | 11.61 ss
# [########################################] | 100% Completed | 8.90 sms
# ACCESS-ESM1-5_r18i1p1f1
# [########################################] | 100% Completed | 12.13 ss
# [########################################] | 100% Completed | 9.28 sms
# ACCESS-ESM1-5_r19i1p1f1
# [########################################] | 100% Completed | 12.02 ss
# [########################################] | 100% Completed | 9.67 sms
# ACCESS-ESM1-5_r1i1p1f1
# [########################################] | 100% Completed | 11.91 ss
# [########################################] | 100% Completed | 9.03 sms
# ACCESS-ESM1-5_r20i1p1f1
# [########################################] | 100% Completed | 12.13 ss
# [########################################] | 100% Completed | 9.84 sms
# ACCESS-ESM1-5_r21i1p1f1
# [########################################] | 100% Completed | 12.12 ss
# [########################################] | 100% Completed | 8.83 sms
# ACCESS-ESM1-5_r22i1p1f1
# [########################################] | 100% Completed | 12.28 ss
# [########################################] | 100% Completed | 9.85 sms
# ACCESS-ESM1-5_r23i1p1f1
# [########################################] | 100% Completed | 11.36 ss
# [########################################] | 100% Completed | 7.90 sms
# ACCESS-ESM1-5_r24i1p1f1
# [########################################] | 100% Completed | 10.64 ss
# [########################################] | 100% Completed | 8.52 sms
# ACCESS-ESM1-5_r25i1p1f1
# [########################################] | 100% Completed | 12.14 ss
# [########################################] | 100% Completed | 8.03 sms
# ACCESS-ESM1-5_r26i1p1f1
# [########################################] | 100% Completed | 11.75 ss
# [########################################] | 100% Completed | 8.72 sms
# ACCESS-ESM1-5_r27i1p1f1
# [########################################] | 100% Completed | 11.87 ss
# [########################################] | 100% Completed | 8.62 sms
# ACCESS-ESM1-5_r28i1p1f1
# [########################################] | 100% Completed | 12.30 ss
# [########################################] | 100% Completed | 9.13 sms
# ACCESS-ESM1-5_r29i1p1f1
# [########################################] | 100% Completed | 12.44 ss
# [########################################] | 100% Completed | 9.25 sms
# ACCESS-ESM1-5_r2i1p1f1
# [########################################] | 100% Completed | 11.25 ss
# [########################################] | 100% Completed | 9.06 sms
# ACCESS-ESM1-5_r30i1p1f1
# [########################################] | 100% Completed | 11.75 ss
# [########################################] | 100% Completed | 9.12 sms
# ACCESS-ESM1-5_r31i1p1f1
# [########################################] | 100% Completed | 12.38 ss
# [########################################] | 100% Completed | 8.92 sms
# ACCESS-ESM1-5_r32i1p1f1
# [########################################] | 100% Completed | 13.59 ss
# [########################################] | 100% Completed | 8.76 sms
# ACCESS-ESM1-5_r33i1p1f1
# [########################################] | 100% Completed | 11.59 ss
# [########################################] | 100% Completed | 9.96 sms
# ACCESS-ESM1-5_r34i1p1f1
# [########################################] | 100% Completed | 15.57 ss
# [########################################] | 100% Completed | 9.63 sms
# ACCESS-ESM1-5_r35i1p1f1
# [########################################] | 100% Completed | 14.11 ss
# [########################################] | 100% Completed | 11.95 ss
# ACCESS-ESM1-5_r36i1p1f1
# [########################################] | 100% Completed | 14.18 ss
# [########################################] | 100% Completed | 9.25 sms
# ACCESS-ESM1-5_r37i1p1f1
# [########################################] | 100% Completed | 11.20 ss
# [########################################] | 100% Completed | 11.17 ss
# ACCESS-ESM1-5_r38i1p1f1
# [########################################] | 100% Completed | 11.81 ss
# [########################################] | 100% Completed | 9.38 sms
# ACCESS-ESM1-5_r39i1p1f1
# [########################################] | 100% Completed | 11.87 ss
# [########################################] | 100% Completed | 8.77 sms
# ACCESS-ESM1-5_r3i1p1f1
# [########################################] | 100% Completed | 11.88 ss
# [########################################] | 100% Completed | 9.76 sms
# ACCESS-ESM1-5_r40i1p1f1
# [########################################] | 100% Completed | 13.90 ss
# [########################################] | 100% Completed | 13.61 ss
# ACCESS-ESM1-5_r4i1p1f1
# [########################################] | 100% Completed | 12.98 ss
# [########################################] | 100% Completed | 11.59 ss
# ACCESS-ESM1-5_r5i1p1f1
# [########################################] | 100% Completed | 14.39 ss
# [########################################] | 100% Completed | 10.31 ss
# ACCESS-ESM1-5_r6i1p1f1
# [########################################] | 100% Completed | 15.20 s
# [########################################] | 100% Completed | 10.21 ss
# ACCESS-ESM1-5_r7i1p1f1
# [########################################] | 100% Completed | 13.81 ss
# [########################################] | 100% Completed | 10.56 ss
# ACCESS-ESM1-5_r8i1p1f1
# [########################################] | 100% Completed | 13.20 ss
# [########################################] | 100% Completed | 10.98 ss
# ACCESS-ESM1-5_r9i1p1f1
# [########################################] | 100% Completed | 12.74 s
# [########################################] | 100% Completed | 11.08 ss
# CanESM5_r10i1p1f1
# [########################################] | 100% Completed | 13.02 ss
# [########################################] | 100% Completed | 11.80 ss
# CanESM5_r10i1p2f1
# [########################################] | 100% Completed | 11.48 ss
# [########################################] | 100% Completed | 10.04 ss
# CanESM5_r1i1p1f1
# [########################################] | 100% Completed | 13.81 ss
# [########################################] | 100% Completed | 10.27 ss
# CanESM5_r1i1p2f1
# [########################################] | 100% Completed | 12.25 ss
# [########################################] | 100% Completed | 8.84 sms
# CanESM5_r2i1p1f1
# [########################################] | 100% Completed | 10.97 ss
# [########################################] | 100% Completed | 8.30 sms
# CanESM5_r2i1p2f1
# [########################################] | 100% Completed | 10.68 ss
# [########################################] | 100% Completed | 8.92 sms
# CanESM5_r3i1p1f1
# [########################################] | 100% Completed | 12.03 ss
# [########################################] | 100% Completed | 9.25 sms
# CanESM5_r3i1p2f1
# [########################################] | 100% Completed | 12.47 ss
# [########################################] | 100% Completed | 9.83 sms
# CanESM5_r4i1p1f1
# [########################################] | 100% Completed | 12.97 ss
# [########################################] | 100% Completed | 11.49 ss
# CanESM5_r4i1p2f1
# [########################################] | 100% Completed | 12.48 ss
# [########################################] | 100% Completed | 9.84 sms
# CanESM5_r5i1p1f1
# [########################################] | 100% Completed | 11.54 ss
# [########################################] | 100% Completed | 10.25 ss
# CanESM5_r5i1p2f1
# [########################################] | 100% Completed | 12.19 ss
# [########################################] | 100% Completed | 9.26 sms
# CanESM5_r6i1p1f1
# [########################################] | 100% Completed | 13.09 ss
# [########################################] | 100% Completed | 8.87 sms
# CanESM5_r6i1p2f1
# [########################################] | 100% Completed | 13.06 ss
# [########################################] | 100% Completed | 9.74 sms
# CanESM5_r7i1p1f1
# [########################################] | 100% Completed | 12.31 ss
# [########################################] | 100% Completed | 8.85 sms
# CanESM5_r7i1p2f1
# [########################################] | 100% Completed | 13.09 ss
# [########################################] | 100% Completed | 9.53 sms
# CanESM5_r8i1p1f1
# [########################################] | 100% Completed | 12.50 ss
# [########################################] | 100% Completed | 8.92 sms
# CanESM5_r8i1p2f1
# [########################################] | 100% Completed | 12.38 ss
# [########################################] | 100% Completed | 13.06 ss
# CanESM5_r9i1p1f1

# %%
TXX_IV = xr.concat(txx_dsets_iv, dim ="GCM_variant").to_dataset(name = 'TXX_IV')
new_dsets = []
for dset in seasonal_dsets_iv:
    dset['time'] = pd.to_datetime(dset.time.dt.strftime("%Y-%m-%d"))
    new_dsets.append(dset)
DJF_IV = xr.concat(new_dsets, dim ="GCM_variant").to_dataset(name = 'DJF_IV')

# %%
# DJF_IV =  DJF_IV.drop("season").rename({"time":"year"})

# %%
# DJF_IV['year'] =  DJF_IV.year.dt.year

# %%
TXX_IV = xr.concat(txx_dsets_iv, dim ="GCM_variant").to_dataset(name = 'TXX_IV')
new_dsets = []
for dset in seasonal_dsets_iv:
    dset['time'] = pd.to_datetime(dset.time.dt.strftime("%Y-%m-%d"))
    new_dsets.append(dset)
DJF_IV = xr.concat(new_dsets, dim ="GCM_variant").to_dataset(name = 'DJF_IV')
#DJF_IV['GCM_variant'] = TXX_IV .GCM_variant.values

merged_dset_TXX_DJF_IV = xr.merge([TXX_IV, DJF_IV])
merged_dset_TXX_DJF_IV.to_netcdf('/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/internal_variability_data/Multi_Model_Decomposition_tasmax_LE_IV_v250425.nc')

# %%
ssps = ['ssp370']
# first get the historical
historical_files = get_list_of_files(varname = "pr", GCM_variant_list = accessesm1 + canesm,  ssp = "historical", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
ssp370_files = get_list_of_files(varname = "pr", GCM_variant_list = accessesm1 + canesm,  ssp = "ssp370", base_path ='/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public')
print(len(historical_files))
seasonal_dsets_iv_pr = []
txx_dsets_iv_pr = []
for i, file in enumerate(historical_files):
    historical_tx = xr.open_dataset(historical_files[i]).sel(time = slice("1995","2014")).pr
    # first compute a climatological reference
    txx_reference = historical_tx.groupby('time.year').max().mean("year") # a reference climatology
    seasonal_reference = historical_tx.groupby('time.season').mean().sel(season = 'DJF')
    txx_ssp370, seasonal_ssp370 = compute_future_reference(ssp370_files[i], txx_reference, seasonal_reference, historical_tx, varname = "pr")
    
    # this is the large ensemble code
    variant = file.split('/')[-1].split('_')[5]
    gcm = ssp370_files[i].split('/')[-1].split('_')[3]
    
    
    txx_dset = txx_ssp370.expand_dims({"GCM_variant":1})
    seasonal_dset = seasonal_ssp370.expand_dims({"GCM_variant":1})
    print(f'{gcm}_{variant}')
    
    txx_dset['GCM_variant'] = (('GCM_variant'), [f'{gcm}_{variant}'])
    txx_dset['GCM'] = (('GCM_variant'), [f'{gcm}'])
    seasonal_dset['GCM_variant'] = (('GCM_variant'), [f'{gcm}_{variant}'])
    seasonal_dset['GCM'] = (('GCM_variant'), [f'{gcm}'])
    txx_dsets_iv_pr.append(txx_dset)
    seasonal_dsets_iv_pr.append(seasonal_dset)
# Out:
# 59
# [########################################] | 100% Completed | 12.71 ss
# [########################################] | 100% Completed | 9.52 sms
# ACCESS-ESM1-5_r10i1p1f1
# [########################################] | 100% Completed | 12.71 ss
# [########################################] | 100% Completed | 9.61 sms
# ACCESS-ESM1-5_r11i1p1f1
# [########################################] | 100% Completed | 11.76 ss
# [########################################] | 100% Completed | 10.44 ss
# ACCESS-ESM1-5_r12i1p1f1
# [########################################] | 100% Completed | 11.88 ss
# [########################################] | 100% Completed | 8.95 sms
# ACCESS-ESM1-5_r13i1p1f1
# [########################################] | 100% Completed | 12.25 ss
# [########################################] | 100% Completed | 9.57 sms
# ACCESS-ESM1-5_r14i1p1f1
# [########################################] | 100% Completed | 13.31 ss
# [########################################] | 100% Completed | 11.57 ss
# ACCESS-ESM1-5_r15i1p1f1
# [########################################] | 100% Completed | 16.00 ss
# [########################################] | 100% Completed | 12.59 ss
# ACCESS-ESM1-5_r16i1p1f1
# [########################################] | 100% Completed | 14.55 ss
# [########################################] | 100% Completed | 14.68 ss
# ACCESS-ESM1-5_r17i1p1f1
# [########################################] | 100% Completed | 18.29 ss
# [########################################] | 100% Completed | 11.39 ss
# ACCESS-ESM1-5_r18i1p1f1
# [########################################] | 100% Completed | 11.47 ss
# [########################################] | 100% Completed | 9.83 sms
# ACCESS-ESM1-5_r19i1p1f1
# [########################################] | 100% Completed | 14.04 ss
# [########################################] | 100% Completed | 9.89 sms
# ACCESS-ESM1-5_r1i1p1f1
# [########################################] | 100% Completed | 11.80 ss
# [########################################] | 100% Completed | 10.28 ss
# ACCESS-ESM1-5_r20i1p1f1
# [########################################] | 100% Completed | 13.10 ss
# [########################################] | 100% Completed | 9.52 sms
# ACCESS-ESM1-5_r21i1p1f1
# [########################################] | 100% Completed | 14.06 ss
# [########################################] | 100% Completed | 11.78 ss
# ACCESS-ESM1-5_r22i1p1f1
# [########################################] | 100% Completed | 12.97 ss
# [########################################] | 100% Completed | 10.05 ss
# ACCESS-ESM1-5_r23i1p1f1
# [########################################] | 100% Completed | 12.28 ss
# [########################################] | 100% Completed | 10.02 ss
# ACCESS-ESM1-5_r24i1p1f1
# [########################################] | 100% Completed | 12.45 ss
# [########################################] | 100% Completed | 9.35 sms
# ACCESS-ESM1-5_r25i1p1f1
# [########################################] | 100% Completed | 11.45 ss
# [########################################] | 100% Completed | 10.14 ss
# ACCESS-ESM1-5_r26i1p1f1
# [########################################] | 100% Completed | 13.69 ss
# [########################################] | 100% Completed | 9.43 sms
# ACCESS-ESM1-5_r27i1p1f1
# [########################################] | 100% Completed | 13.48 ss
# [########################################] | 100% Completed | 8.85 sms
# ACCESS-ESM1-5_r28i1p1f1
# [########################################] | 100% Completed | 12.06 ss
# [########################################] | 100% Completed | 9.23 sms
# ACCESS-ESM1-5_r29i1p1f1
# [########################################] | 100% Completed | 12.47 ss
# [########################################] | 100% Completed | 10.05 ss
# ACCESS-ESM1-5_r2i1p1f1
# [########################################] | 100% Completed | 12.79 ss
# [########################################] | 100% Completed | 8.83 sms
# ACCESS-ESM1-5_r30i1p1f1
# [########################################] | 100% Completed | 12.54 ss
# [########################################] | 100% Completed | 10.14 ss
# ACCESS-ESM1-5_r31i1p1f1
# [########################################] | 100% Completed | 12.56 ss
# [########################################] | 100% Completed | 10.76 ss
# ACCESS-ESM1-5_r32i1p1f1
# [########################################] | 100% Completed | 13.58 ss
# [########################################] | 100% Completed | 11.35 ss
# ACCESS-ESM1-5_r33i1p1f1
# [########################################] | 100% Completed | 12.18 ss
# [########################################] | 100% Completed | 8.74 sms
# ACCESS-ESM1-5_r34i1p1f1
# [########################################] | 100% Completed | 11.93 ss
# [########################################] | 100% Completed | 8.76 sms
# ACCESS-ESM1-5_r35i1p1f1
# [########################################] | 100% Completed | 13.29 ss
# [########################################] | 100% Completed | 9.43 sms
# ACCESS-ESM1-5_r36i1p1f1
# [########################################] | 100% Completed | 13.79 ss
# [########################################] | 100% Completed | 9.44 sms
# ACCESS-ESM1-5_r37i1p1f1
# [########################################] | 100% Completed | 12.08 ss
# [########################################] | 100% Completed | 8.97 sms
# ACCESS-ESM1-5_r38i1p1f1
# [########################################] | 100% Completed | 14.11 ss
# [########################################] | 100% Completed | 9.95 sms
# ACCESS-ESM1-5_r39i1p1f1
# [########################################] | 100% Completed | 14.27 ss
# [########################################] | 100% Completed | 9.12 sms
# ACCESS-ESM1-5_r3i1p1f1
# [########################################] | 100% Completed | 14.13 ss
# [########################################] | 100% Completed | 9.87 sms
# ACCESS-ESM1-5_r40i1p1f1
# [########################################] | 100% Completed | 13.38 ss
# [########################################] | 100% Completed | 9.22 sms
# ACCESS-ESM1-5_r4i1p1f1
# [########################################] | 100% Completed | 11.08 ss
# [########################################] | 100% Completed | 9.09 sms
# ACCESS-ESM1-5_r5i1p1f1
# [########################################] | 100% Completed | 10.54 ss
# [########################################] | 100% Completed | 8.21 sms
# ACCESS-ESM1-5_r6i1p1f1
# [########################################] | 100% Completed | 11.92 ss
# [########################################] | 100% Completed | 8.59 sms
# ACCESS-ESM1-5_r7i1p1f1
# [########################################] | 100% Completed | 11.35 ss
# [########################################] | 100% Completed | 8.30 sms
# ACCESS-ESM1-5_r8i1p1f1
# [########################################] | 100% Completed | 11.60 ss
# [########################################] | 100% Completed | 8.07 sms
# ACCESS-ESM1-5_r9i1p1f1
# [########################################] | 100% Completed | 12.34 ss
# [########################################] | 100% Completed | 8.62 sms
# CanESM5_r10i1p1f1
# [########################################] | 100% Completed | 13.51 ss
# [########################################] | 100% Completed | 8.63 sms
# CanESM5_r10i1p2f1
# [########################################] | 100% Completed | 12.08 ss
# [########################################] | 100% Completed | 8.95 sms
# CanESM5_r1i1p1f1
# [########################################] | 100% Completed | 11.69 ss
# [########################################] | 100% Completed | 8.81 sms
# CanESM5_r1i1p2f1
# [########################################] | 100% Completed | 10.88 ss
# [########################################] | 100% Completed | 8.11 sms
# CanESM5_r2i1p1f1
# [########################################] | 100% Completed | 11.23 ss
# [########################################] | 100% Completed | 8.14 sms
# CanESM5_r2i1p2f1
# [########################################] | 100% Completed | 11.07 ss
# [########################################] | 100% Completed | 8.02 sms
# CanESM5_r3i1p1f1
# [########################################] | 100% Completed | 12.07 ss
# [########################################] | 100% Completed | 9.44 sms
# CanESM5_r3i1p2f1
# [########################################] | 100% Completed | 12.40 ss
# [########################################] | 100% Completed | 8.24 sms
# CanESM5_r4i1p1f1
# [########################################] | 100% Completed | 10.76 ss
# [########################################] | 100% Completed | 8.18 sms
# CanESM5_r4i1p2f1
# [########################################] | 100% Completed | 10.76 ss
# [########################################] | 100% Completed | 8.52 sms
# CanESM5_r5i1p1f1
# [########################################] | 100% Completed | 10.97 ss
# [########################################] | 100% Completed | 8.43 sms
# CanESM5_r5i1p2f1
# [########################################] | 100% Completed | 10.99 ss
# [########################################] | 100% Completed | 8.47 sms
# CanESM5_r6i1p1f1
# [########################################] | 100% Completed | 11.17 ss
# [########################################] | 100% Completed | 8.43 sms
# CanESM5_r6i1p2f1
# [########################################] | 100% Completed | 12.36 ss
# [########################################] | 100% Completed | 9.66 sms
# CanESM5_r7i1p1f1
# [########################################] | 100% Completed | 11.55 ss
# [########################################] | 100% Completed | 8.61 sms
# CanESM5_r7i1p2f1
# [########################################] | 100% Completed | 10.64 ss
# [########################################] | 100% Completed | 8.11 sms
# CanESM5_r8i1p1f1
# [########################################] | 100% Completed | 10.45 ss
# [########################################] | 100% Completed | 8.08 sms
# CanESM5_r8i1p2f1
# [########################################] | 100% Completed | 13.98 ss
# [########################################] | 100% Completed | 9.83 sms
# CanESM5_r9i1p1f1

# %%
# TXX_IV = xr.concat(txx_dsets_iv_pr, dim ="GCM_variant").to_dataset(name = 'RX1Day_IV')
# DJF_IV = xr.concat(seasonal_dsets_iv_pr, dim ="GCM_variant").to_dataset(name = 'DJF_IV')
# merged_dset_TXX_DJF_IV_pr = xr.merge([TXX_IV, DJF_IV])
# merged_dset_TXX_DJF_IV_pr.to_netcdf('/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/internal_variability_data/Multi_Model_Decomposition_pr_LE_IV.nc')

# %%
TXX_IV = xr.concat(txx_dsets_iv_pr, dim ="GCM_variant").to_dataset(name = 'RX1Day_IV')
new_dsets = []
for dset in seasonal_dsets_iv_pr:
    dset['time'] = pd.to_datetime(dset.time.dt.strftime("%Y-%m-%d"))
    new_dsets.append(dset)
DJF_IV = xr.concat(new_dsets, dim ="GCM_variant").to_dataset(name = 'DJF_IV_pr')


merged_dset_TXX_DJF_IV = xr.merge([TXX_IV, DJF_IV])
merged_dset_TXX_DJF_IV.to_netcdf('/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/internal_variability_data/Multi_Model_Decomposition_pr_LE_IV_v250425_percentage.nc')

# %%
concats = xr.concat(full_dset, dim ="ssp")

# %%
concats.to_netcdf(r'/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/TXX_internal_variability_smoothing_decomposition.nc')

# %%
print(len(files_glob_tx))
# Out:
# 77

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
concat_internal_variability = xr.open_dataset(r'/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/TXX_internal_variability_smoothing_decomposition_contribution.nc')

# %%
concat_internal_variability = concat_internal_variability.stack(z =['GCM', 'GCM_variant']).dropna("z")

# %%
concat_internal_variability['tasmax_resid_2'] = (('ssp','lat','lon','year','z'), concat_internal_variability.tasmax_resid.transpose("ssp","lat","lon","time","z").values)

# %%
concat_internal_variability['tasmax_resid_2'] = concat_internal_variability['tasmax_resid_2'] + concat_internal_variability['tasmax']

# %%
var1 = concat_internal_variability['tasmax_resid_2'].squeeze().sel(z = concat_internal_variability.GCM =='ACCESS-ESM1-5').var("z")
var2 = concat_internal_variability['tasmax_resid_2'].squeeze().sel(z = concat_internal_variability.GCM =='CanESM5').var("z")

# %%
original_array = xr.open_dataset(r'/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/TXX_internal_variability_smoothing_decomposition.nc')

# %%
I = original_array.tasmax_resid.var(["year","ssp"]).mean(["GCM"])

# %%
fig, ax = plt.subplots()
var2.mean(["lat","lon"]).plot(ax = ax,label ='IV (CanESM5)')
var1.mean(["lat","lon"]).plot(ax = ax,label ='IV (ACCESS-ESM1-5)')
ax.axhline(I.mean(["lat","lon"]), color ='k', ls ='--', label ='H&S09')
ax.set_ylabel('TXX Internal Variability ($\sigma^2$)', weight ='bold')
ax.legend()
ax.set_title('Internal Variability: Large Ensembles vs H&S09', weight ='bold')
# Out:
# Text(0.5, 1.0, 'Internal Variability: Large Ensembles vs H&S09')

# %%
fig, ax = plt.subplots(1,3, subplot_kw = dict(projection = ccrs.PlateCarree(central_longitude =171.77)), figsize = (12, 6))
cs = np.sqrt(var1).mean(["year"]).plot(ax = ax[0], transform = ccrs.PlateCarree(), add_colorbar =False, vmin =0, vmax =2, cmap ='Reds')
np.sqrt(var2).mean(["year"]).plot(ax = ax[1], transform = ccrs.PlateCarree(), add_colorbar =False, vmin =0, vmax =2, cmap ='Reds')
np.sqrt(I).plot(ax = ax[2], transform = ccrs.PlateCarree(), add_colorbar =False, vmin =0, vmax =2, cmap ='Reds')
ax[0].set_title('ACCESS-ESM1-5')
ax[1].set_title('CanESM5')
ax[2].set_title('H&S09')
ax4 = fig.add_axes([0.1, 0.15, 0.8, 0.03])
cbar = fig.colorbar(cs, cax =ax4, orientation = 'horizontal')
cbar.set_label('TXX Internal Variability $\sigma$', weight ='bold')

# %%
I = original_array.tasmax_resid.var(["year","ssp"]).mean(["GCM"])

# %%
M = original_array.var("GCM").mean("ssp").tasmax

# %%
S = original_array.mean("GCM").var("ssp").tasmax

# %%
T = S + M + I

# %%
S_ = S/T
M_ = M/T
I_ = I/T

# %%
fig, ax = plt.subplots(figsize=(8, 6))
lat =-39
lon = 170
ax.stackplot(
    I_.year,
    I_.sel(lat =lat, lon =lon, method ='nearest'),
    S_.sel(lat =lat, lon =lon, method ='nearest'),
    M_.sel(lat =lat, lon =lon, method ='nearest'),
    labels=["Internal Variability", "Scenario Uncertainty","Model Uncertainty" ],
    colors=["blue", "green", "orange"],
)

ax.set_xlabel("Lead Time [years from 2015]", fontsize=12, fontweight='bold')
ax.set_ylabel("Fraction of Total Variance [%]", fontsize=12, fontweight='bold')
ax.set_title("Tasman Sea (-39$\degree$S, 170$\degree$E) ", fontsize=14, fontweight='bold')
ax.legend(loc="upper right")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
lat =-39
lon = 176
ax.stackplot(
    I_.year,
    I_.sel(lat =lat, lon =lon, method ='nearest'),
    S_.sel(lat =lat, lon =lon, method ='nearest'),
    M_.sel(lat =lat, lon =lon, method ='nearest'),
    labels=["Internal Variability", "Scenario Uncertainty","Model Uncertainty" ],
    colors=["blue", "green", "orange"],
)

ax.set_xlabel("Lead Time [years from 2015]", fontsize=12, fontweight='bold')
ax.set_ylabel("Fraction of Total Variance [%]", fontsize=12, fontweight='bold')
ax.set_title("Central North Island (-39$\degree$S, 176$\degree$E)", fontsize=14, fontweight='bold')
ax.legend(loc="upper right")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
lat =-43
lon = 170
ax.stackplot(
    I_.year,
    I_.sel(lat =lat, lon =lon, method ='nearest'),
    S_.sel(lat =lat, lon =lon, method ='nearest'),
    M_.sel(lat =lat, lon =lon, method ='nearest'),
    labels=["Internal Variability", "Scenario Uncertainty","Model Uncertainty" ],
    colors=["blue", "green", "orange"],
)

ax.set_xlabel("Lead Time [years from 2015]", fontsize=12, fontweight='bold')
ax.set_ylabel("Fraction of Total Variance [%]", fontsize=12, fontweight='bold')
ax.set_title("Global, Decadal Mean Surface Air Temperature", fontsize=14, fontweight='bold')
ax.legend(loc="upper right")
plt.show()

# %%
S_mean = S.mean(["lat","lon"])/T.mean(["lat","lon"])
M_mean = M.mean(["lat","lon"])/T.mean(["lat","lon"])
I_mean = I.mean(["lat","lon"])/T.mean(["lat","lon"])

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.stackplot(
    I_mean.year,
    I_mean,
    S_mean,
    M_mean,
    labels=["Internal Variability", "Scenario Uncertainty","Model Uncertainty" ],
    colors=["blue", "green", "orange"],
)

ax.set_xlabel("Lead Time [years from 2015]", fontsize=12, fontweight='bold')
ax.set_ylabel("Fraction of Total Variance [%]", fontsize=12, fontweight='bold')
ax.set_title("Global, Decadal Mean Surface Air Temperature", fontsize=14, fontweight='bold')
ax.legend(loc="upper right")
plt.show()

# %%
fig, ax = plt.subplots(2,3, figsize = (18, 10), subplot_kw = dict(projection =ccrs.PlateCarree(central_longitude =171.77)))
M_.isel(year =-1).plot(ax =ax[1,0], cmap ='Oranges', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())
S_.isel(year =-1).plot(ax =ax[1,1], cmap ='Greens', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())
I_.isel(year =-1).plot(ax =ax[1,2], cmap ='Blues', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())

M_.isel(year =0).plot(ax =ax[0,0], cmap ='Oranges', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())
S_.isel(year =0).plot(ax =ax[0,1], cmap ='Greens', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())
I_.isel(year =0).plot(ax =ax[0,2], cmap ='Blues', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())
ax[0,0].set_title('Model Uncertainty', weight ='bold', fontsize =15)
ax[0,1].set_title('Scenario Uncertainty', weight ='bold', fontsize =15)
ax[0,2].set_title('Internal Variability Uncertainty', weight ='bold', fontsize =15)
ax[1,0].set_title(' ')
ax[1,1].set_title(' ')
ax[1,2].set_title(' ')
ax[0,0].coastlines('10m')
ax[0,1].coastlines('10m')
ax[0,2].coastlines('10m')
ax[1,0].coastlines('10m')
ax[1,1].coastlines('10m')
ax[1,2].coastlines('10m')
ax[0,0].text(160, -41, '2015', weight ='bold', transform = ccrs.PlateCarree(), fontsize = 18)
ax[1,0].text(160, -41, '2099', weight ='bold', transform = ccrs.PlateCarree(), fontsize = 18)
# Out:
# Text(160, -41, '2099')

# %%
ssps = ['ssp126','ssp245', 'ssp585']
import glob
full_dset = []
for ssp in ssps:
    #files_glob_tx = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/{ssp}/daily/tasmax/tasmax_ScenarioMIP_*{ssp}*_day_NZ12km_NIWA-REMS_tasmax_v280125.nc')
    files_glob_pr = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/{ssp}/daily/pr/pr_ScenarioMIP_*{ssp}*_day_NZ12km_NIWA-REMS_pr_v280125.nc')
    ssp_dset = []
    for file in files_glob_pr:
        #print(files_glob_tx)
        print(file)
        tx = xr.open_dataset(file)
        variant = file.split('/')[-1].split('_')[5]
        ssp = file.split('/')[-1].split('_')[4]
        gcm = file.split('/')[-1].split('_')[3]
        txx = tx.groupby('time.year').max()
        txx_smoothed = xr.apply_ufunc(func, txx.isel(year = slice(0, -1)), input_core_dims=[["year"]], output_core_dims =[["year"]], output_dtypes =[float], vectorize =True,
                             dask = 'parallelized')
        txx_smoothed['tasmax_resid'] = (('year','lat','lon'), (txx.isel(year = slice(0, -1)) -  txx_smoothed).pr.values)
        txx_smoothed = txx_smoothed.expand_dims({"GCM":1})
        txx_smoothed['GCM'] = (('GCM'), [gcm])
        txx_smoothed.attrs['variant'] = [variant]
        ssp_dset.append(txx_smoothed)
    concat_dset = xr.concat(ssp_dset, dim ="GCM")
    concat_dset = concat_dset.expand_dims({"ssp":1})
    concat_dset['ssp'] = (('ssp'), [ssp])
    full_dset.append(concat_dset)
        
    
    #print(len(files_glob))
# Out:
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_NASA-GISS_GISS-E2-1-G_ssp126_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_MOHC_UKESM1-0-LL_ssp126_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_IPSL_IPSL-CM6A-LR_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_EC-Earth-Consortium_EC-Earth3-Veg-LR_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_INM_INM-CM4-8_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_CCCR-IITM_IITM-ESM_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_INM_INM-CM5-0_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_CSIRO-ARCCSS_ACCESS-CM2_ssp126_r4i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_NCC_NorESM2-MM_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_CCCma_CanESM5_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_DKRZ_MPI-ESM1-2-HR_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_EC-Earth-Consortium_EC-Earth3_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_NCC_NorESM2-LM_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_AS-RCEC_TaiESM1_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_EC-Earth-Consortium_EC-Earth3-Veg_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_MPI-M_MPI-ESM1-2-LR_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_CMCC_CMCC-CM2-SR5_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_CNRM-CERFACS_CNRM-CM6-1_ssp126_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp126/daily/pr/pr_ScenarioMIP_CMCC_CMCC-ESM2_ssp126_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_INM_INM-CM4-8_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_INM_INM-CM5-0_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_EC-Earth-Consortium_EC-Earth3-Veg-LR_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_CSIRO-ARCCSS_ACCESS-CM2_ssp245_r4i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_IPSL_IPSL-CM6A-LR_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_MOHC_UKESM1-0-LL_ssp245_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_NCC_NorESM2-MM_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_AS-RCEC_TaiESM1_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_MPI-M_MPI-ESM1-2-LR_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_CMCC_CMCC-ESM2_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_CMCC_CMCC-CM2-SR5_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_DKRZ_MPI-ESM1-2-HR_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_EC-Earth-Consortium_EC-Earth3_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_EC-Earth-Consortium_EC-Earth3-Veg_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_CCCma_CanESM5_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_NASA-GISS_GISS-E2-1-G_ssp245_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_CNRM-CERFACS_CNRM-CM6-1_ssp245_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_NCC_NorESM2-LM_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp245/daily/pr/pr_ScenarioMIP_CCCR-IITM_IITM-ESM_ssp245_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_NASA-GISS_GISS-E2-1-G_ssp585_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_CSIRO_ACCESS-ESM1-5_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_CCCma_CanESM5_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_MOHC_UKESM1-0-LL_ssp585_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_INM_INM-CM5-0_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_CMCC_CMCC-ESM2_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_CMCC_CMCC-CM2-SR5_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_EC-Earth-Consortium_EC-Earth3_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_EC-Earth-Consortium_EC-Earth3-Veg-LR_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_NCC_NorESM2-MM_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_DKRZ_MPI-ESM1-2-HR_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_EC-Earth-Consortium_EC-Earth3-Veg_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_MPI-M_MPI-ESM1-2-LR_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_CSIRO-ARCCSS_ACCESS-CM2_ssp585_r4i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_INM_INM-CM4-8_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_CCCR-IITM_IITM-ESM_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_CNRM-CERFACS_CNRM-CM6-1_ssp585_r1i1p1f2_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_NCC_NorESM2-LM_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_IPSL_IPSL-CM6A-LR_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc
# /nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp585/daily/pr/pr_ScenarioMIP_AS-RCEC_TaiESM1_ssp585_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc

# %%
concats = xr.concat(full_dset, dim ="ssp")

# %%
concats = xr.concat(full_dset, dim ="ssp")
concats.to_netcdf('/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/RX1day_internal_variability_smoothing_decomposition_contribution.nc')

# %%
I = concats.tasmax_resid.var(["year"]).mean(["GCM","ssp"])
M = concats.var("GCM").mean("ssp").pr
S = concats.mean("GCM").var("ssp").pr
T = S + M + I
S_ = S/T
M_ = M/T
I_ = I/T

# %%
(100*(concats.pr.isel(ssp=1, GCM =6).isel(year =-1)- concats.pr.isel(ssp=2, GCM =0).isel(year =0))/concats.pr.isel(ssp=2, GCM =0).isel(year =0)).plot(vmin =-30, vmax =30, cmap ='BrBG')#.sel(lat =lat, lon=lon, method ='nearest').plot()

# %%
#T.sel(lat =lat, lon =lon, method ='nearest').plot()
I_.sel(lat =lat, lon =lon, method ='nearest').plot()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
lat =-39
lon = 170
ax.stackplot(
    I_.year,
    I_.sel(lat =lat, lon =lon, method ='nearest'),
    S_.sel(lat =lat, lon =lon, method ='nearest'),
    M_.sel(lat =lat, lon =lon, method ='nearest'),
    labels=["Internal Variability", "Scenario Uncertainty","Model Uncertainty" ],
    colors=["blue", "green", "orange"],
)

ax.set_xlabel("Lead Time [years from 2015]", fontsize=12, fontweight='bold')
ax.set_ylabel("Fraction of Total Variance [%]", fontsize=12, fontweight='bold')
ax.set_title("Tasman Sea (-39$\degree$S, 170$\degree$E) ", fontsize=14, fontweight='bold')
ax.legend(loc="upper right")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
lat =-39
lon = 176
ax.stackplot(
    I_.year,
    I_.sel(lat =lat, lon =lon, method ='nearest'),
    S_.sel(lat =lat, lon =lon, method ='nearest'),
    M_.sel(lat =lat, lon =lon, method ='nearest'),
    labels=["Internal Variability", "Scenario Uncertainty","Model Uncertainty" ],
    colors=["blue", "green", "orange"],
)

ax.set_xlabel("Lead Time [years from 2015]", fontsize=12, fontweight='bold')
ax.set_ylabel("Fraction of Total Variance [%]", fontsize=12, fontweight='bold')
ax.set_title("Central North Island (-39$\degree$S, 170$\degree$E) ", fontsize=14, fontweight='bold')
ax.legend(loc="upper right")
plt.show()

# %%
fig, ax = plt.subplots(2,3, figsize = (18, 10), subplot_kw = dict(projection =ccrs.PlateCarree(central_longitude =171.77)))
M_.isel(year =-1).plot(ax =ax[1,0], cmap ='Oranges', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())
S_.isel(year =-1).plot(ax =ax[1,1], cmap ='Greens', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())
I_.isel(year =-1).plot(ax =ax[1,2], cmap ='Blues', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())

M_.isel(year =0).plot(ax =ax[0,0], cmap ='Oranges', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())
S_.isel(year =0).plot(ax =ax[0,1], cmap ='Greens', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())
I_.isel(year =0).plot(ax =ax[0,2], cmap ='Blues', vmin =0, vmax =0.7, transform = ccrs.PlateCarree())
ax[0,0].set_title('Model Uncertainty', weight ='bold', fontsize =15)
ax[0,1].set_title('Scenario Uncertainty', weight ='bold', fontsize =15)
ax[0,2].set_title('Internal Variability Uncertainty', weight ='bold', fontsize =15)
ax[1,0].set_title(' ')
ax[1,1].set_title(' ')
ax[1,2].set_title(' ')
ax[0,0].coastlines('10m')
ax[0,1].coastlines('10m')
ax[0,2].coastlines('10m')
ax[1,0].coastlines('10m')
ax[1,1].coastlines('10m')
ax[1,2].coastlines('10m')
ax[0,0].text(160, -41, '2015', weight ='bold', transform = ccrs.PlateCarree(), fontsize = 18)
ax[1,0].text(160, -41, '2099', weight ='bold', transform = ccrs.PlateCarree(), fontsize = 18)
# Out:
# Text(160, -41, '2099')

# %%
ssps = ['ssp370']
full_dset = []
for ssp in ssps:
    #files_glob_tx = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/{ssp}/daily/tasmax/tasmax_ScenarioMIP_*{ssp}*_day_NZ12km_NIWA-REMS_tasmax_v280125.nc')
    files_glob_pr = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/{ssp}/daily/pr/pr_ScenarioMIP_*{ssp}*_day_NZ12km_NIWA-REMS_pr_v280125.nc')
    ssp_dset = []
    for file in files_glob_pr:
        print('na')
        if ('CanESM5' in file) | ('ACCESS-ESM1-5' in file):
            #print(files_glob_tx)
            
            tx = xr.open_dataset(file)
            variant = file.split('/')[-1].split('_')[5]
            ssp = file.split('/')[-1].split('_')[4]
            gcm = file.split('/')[-1].split('_')[3]
            print(gcm, variant, ssp)
            txx = tx.groupby('time.year').max()
            txx_smoothed = xr.apply_ufunc(func, txx.isel(year = slice(0, -1)), input_core_dims=[["year"]], output_core_dims =[["year"]], output_dtypes =[float], vectorize =True,
                                 dask = 'parallelized')
            txx_smoothed['tasmax_resid'] = (('year','lat','lon'), (txx.isel(year = slice(0, -1)) -  txx_smoothed).pr.values)
            txx_smoothed = txx_smoothed.expand_dims({"GCM_variant":1})
            txx_smoothed['GCM_variant'] = (('GCM_variant'), [f'{gcm}_{variant}'])
            txx_smoothed.attrs['variant'] = [variant]
            ssp_dset.append(txx_smoothed)
    concat_dset = xr.concat(ssp_dset, dim ='GCM_variant')
    concat_dset = concat_dset.expand_dims({"ssp":1})
    concat_dset['ssp'] = (('ssp'), [ssp])
    full_dset.append(concat_dset)

# %% [markdown]
# # Seems like there are some interesting results with this large ensemble

# %%
ssps = ['ssp370']
full_dset = []
for ssp in ssps:
    #files_glob_tx = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/{ssp}/daily/tasmax/tasmax_ScenarioMIP_*{ssp}*_day_NZ12km_NIWA-REMS_tasmax_v280125.nc')
    files_glob_pr = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/{ssp}/daily/pr/pr_ScenarioMIP_*{ssp}*_day_NZ12km_NIWA-REMS_pr_v280125.nc')
    ssp_dset = []
    for file in files_glob_pr:
        print('na')
        if ('CanESM5' in file) | ('ACCESS-ESM1-5' in file):
            #print(files_glob_tx)
            
            tx = xr.open_dataset(file)
            variant = file.split('/')[-1].split('_')[5]
            ssp = file.split('/')[-1].split('_')[4]
            gcm = file.split('/')[-1].split('_')[3]
            print(gcm, variant, ssp)
            txx = tx.groupby('time.year').max()
            txx_smoothed = xr.apply_ufunc(func, txx.isel(year = slice(0, -1)), input_core_dims=[["year"]], output_core_dims =[["year"]], output_dtypes =[float], vectorize =True,
                                 dask = 'parallelized')
            txx_smoothed['tasmax_resid'] = (('year','lat','lon'), (txx.isel(year = slice(0, -1)) -  txx_smoothed).pr.values)
            txx_smoothed = txx_smoothed.expand_dims({"GCM_variant":1})
            txx_smoothed['GCM_variant'] = (('GCM_variant'), [f'{gcm}_{variant}'])
            txx_smoothed.attrs['variant'] = [variant]
            ssp_dset.append(txx_smoothed)
    concat_dset = xr.concat(ssp_dset, dim ='GCM_variant')
    concat_dset = concat_dset.expand_dims({"ssp":1})
    concat_dset['ssp'] = (('ssp'), [ssp])
    full_dset.append(concat_dset)
# Out:
# na
# ACCESS-ESM1-5 r23i1p1f1 ssp370
# na
# CanESM5 r3i1p2f1 ssp370
# na
# na
# ACCESS-ESM1-5 r2i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r27i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r36i1p1f1 ssp370
# na
# na
# ACCESS-ESM1-5 r28i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r24i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r33i1p1f1 ssp370
# na
# na
# ACCESS-ESM1-5 r20i1p1f1 ssp370
# na
# na
# na
# CanESM5 r8i1p1f1 ssp370
# na
# na
# ACCESS-ESM1-5 r32i1p1f1 ssp370
# na
# na
# ACCESS-ESM1-5 r29i1p1f1 ssp370
# na
# na
# CanESM5 r7i1p2f1 ssp370
# na
# ACCESS-ESM1-5 r18i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r13i1p1f1 ssp370
# na
# na
# ACCESS-ESM1-5 r25i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r9i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r21i1p1f1 ssp370
# na
# na
# CanESM5 r5i1p1f1 ssp370
# na
# na
# ACCESS-ESM1-5 r15i1p1f1 ssp370
# na
# CanESM5 r9i1p1f1 ssp370
# na
# na
# ACCESS-ESM1-5 r1i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r17i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r8i1p1f1 ssp370
# na
# CanESM5 r8i1p2f1 ssp370
# na
# na
# ACCESS-ESM1-5 r39i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r35i1p1f1 ssp370
# na
# na
# CanESM5 r1i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r7i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r16i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r34i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r31i1p1f1 ssp370
# na
# CanESM5 r10i1p1f1 ssp370
# na
# CanESM5 r2i1p2f1 ssp370
# na
# CanESM5 r4i1p2f1 ssp370
# na
# ACCESS-ESM1-5 r11i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r6i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r19i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r14i1p1f1 ssp370
# na
# na
# ACCESS-ESM1-5 r10i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r3i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r26i1p1f1 ssp370
# na
# CanESM5 r3i1p1f1 ssp370
# na
# CanESM5 r1i1p2f1 ssp370
# na
# ACCESS-ESM1-5 r4i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r37i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r38i1p1f1 ssp370
# na
# na
# CanESM5 r6i1p2f1 ssp370
# na
# ACCESS-ESM1-5 r40i1p1f1 ssp370
# na
# CanESM5 r2i1p1f1 ssp370
# na
# CanESM5 r6i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r22i1p1f1 ssp370
# na
# ACCESS-ESM1-5 r30i1p1f1 ssp370
# na
# CanESM5 r5i1p2f1 ssp370
# na
# ACCESS-ESM1-5 r12i1p1f1 ssp370
# na
# CanESM5 r10i1p2f1 ssp370
# na
# ACCESS-ESM1-5 r5i1p1f1 ssp370
# na
# CanESM5 r4i1p1f1 ssp370
# na
# CanESM5 r7i1p1f1 ssp370
# na
# na

# %%
concats = xr.concat(full_dset, dim ="ssp")
concats.to_netcdf('/nesi/project/niwa00018/ML_downscaling_CCAM/AI_large_ensemble/RX1day_internal_variability_smoothing_decomposition_actual_IV.nc')

# %%
(100* ((concats.pr.isel(year =-1) - concats.pr.isel(year =0))/concats.pr.isel(year =0)).sel(GCM_variant = concats.GCM == 'ACCESS-ESM1-5').mean(["GCM_variant"]).squeeze()).plot(vmin =-30, vmax =30, cmap ='BrBG')

# %%
concats.pr.std(["GCM_variant"]).squeeze().mean(["lat","lon"]).plot()

# %%
z1 = (concats.sel(GCM_variant = concats.GCM == 'ACCESS-ESM1-5').pr + concats.sel(GCM_variant = concats.GCM == 'ACCESS-ESM1-5').tasmax_resid)

# %%
variance = z1.var(["GCM_variant"])

# %%
# Some queit interesint properties of Rx1day in this large ensemble

# %%
variance .mean(["lat","lon"]).plot()

# %%
z1.std(["GCM_variant"]).squeeze().mean(["lat","lon"]).plot()

# %%
z1.mean(["GCM_variant"]).squeeze().mean(["lat","lon"]).plot()
z1.mean(["GCM_variant"]).squeeze().mean(["lat","lon"]).plot()

# %%
files_glob_tx = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/{ssp}/daily/tasmax/tasmax_ScenarioMIP_*{ssp}*_day_NZ12km_NIWA-REMS_tasmax_v280125.nc')

# %%
gcm
# Out:
# 'CanESM5'

# %%
tx = xr.open_dataset(r'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/tasmax/tasmax_ScenarioMIP_CCCma_CanESM5_ssp370_r7i1p2f1_day_NZ12km_NIWA-REMS_tasmax_v280125.nc')
pr = xr.open_dataset(r'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/ssp370/daily/pr/pr_ScenarioMIP_CCCma_CanESM5_ssp370_r7i1p2f1_day_NZ12km_NIWA-REMS_pr_v280125.nc')

# %%
txx = tx.groupby('time.year').max()
pr = pr.groupby('time.year').max()

# %%
pr_smoothed = xr.apply_ufunc(func, pr.isel(year = slice(0, -1)), input_core_dims=[["year"]], output_core_dims =[["year"]], output_dtypes =[float], vectorize =True,
                             dask = 'parallelized')

# %%
pr_smoothed
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 172, lon: 179, year: 85)
# Coordinates:
#   * lon       (lon) float32 164.9 165.0 165.1 165.2 ... 183.6 183.7 183.9 184.0
#   * lat       (lat) float32 -51.21 -51.11 -51.0 -50.89 ... -33.07 -32.97 -32.86
#     GCM       <U7 'CanESM5'
#     scenario  <U6 'ssp370'
#   * year      (year) int64 2015 2016 2017 2018 2019 ... 2095 2096 2097 2098 2099
# Data variables:
#     pr        (lat, lon, year) float64 27.79 27.84 27.89 ... 120.8 121.2 121.7

# %%
txx_smoothed = xr.apply_ufunc(func, txx.isel(year = slice(0, -1)), input_core_dims=[["year"]], output_core_dims =[["year"]], output_dtypes =[float], vectorize =True,
                             dask = 'parallelized')

# %%
txx_smoothed.isel(year =-1).tasmax.plot()

# %%
pr.year
# Out:
# <xarray.DataArray 'year' (year: 86)>
# array([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026,
#        2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038,
#        2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050,
#        2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062,
#        2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073, 2074,
#        2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086,
#        2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098,
#        2099, 2100])
# Coordinates:
#     GCM       <U7 'CanESM5'
#     scenario  <U6 'ssp370'
#   * year      (year) int64 2015 2016 2017 2018 2019 ... 2096 2097 2098 2099 2100

# %%
#pr.pr.interp(lat =-39, lon =176, method ='nearest').plot()
txx.tasmax.interp(lat =-39, lon =176, method ='nearest').plot()

# %%
# Define lists
gcm = [
    "MPI-ESM1-2-HR", "ACCESS-CM2", "ACCESS-ESM1-5", "GISS-E2-1-G", "INM-CM4-8",
    "INM-CM5-0", "EC-Earth3", "TaiESM1", "IPSL-CM6A-LR", "MPI-ESM1-2-LR", "NorESM2-LM",
    "NorESM2-MM", "CanESM5", "UKESM1-0-LL", "IITM-ESM", "CMCC-ESM2", "EC-Earth3-Veg-LR",
    "CNRM-CM6-1", "EC-Earth3-Veg", "CMCC-CM2-SR5"
]

variant = [
    "r1i1p1f1", "r4i1p1f1", "r1i1p1f1", "r1i1p1f2", "r1i1p1f1",
    "r1i1p1f1", "r1i1p1f1", "r1i1p1f1", "r1i1p1f1", "r1i1p1f1", "r1i1p1f1",
    "r1i1p1f1", "r1i1p1f1", "r1i1p1f2", "r1i1p1f1", "r1i1p1f1",
    "r1i1p1f1", "r1i1p1f2", "r1i1p1f1", "r1i1p1f1"
]
ssps = ['ssp126','ssp245','ssp370','ssp585']
for i in range(len(gcm)):
    variants = variant[i]
    gcms = gcm[i]
    historical_run = xr.open_mfdataset(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr*{gcms}.nc')
    for ssp in ssps:
        df = xr.open_mfdataset(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr*{gcms}.nc')
# Out:
# KeyboardInterrupt

# %%
files =glob.glob(f'//nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/*.nc')
files
# Out:
# []

# %%
historical_run = xr.open_mfdataset(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr_CMIP_*{gcms}_historical_{variants}_day_NZ12km_NIWA-REMS_pr_v280125.nc')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[552], line 1
# ----> 1 historical_run = xr.open_mfdataset(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_CCAM_public/historical/daily/pr_CMIP_*{gcms}_historical_{variants}_day_NZ12km_NIWA-REMS_pr_v280125.nc')
#
# File /nesi/project/niwa00018/rampaln/envs/ml_env_v2/lib/python3.8/site-packages/xarray/backends/api.py:874, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     871     paths = [str(p) if isinstance(p, Path) else p for p in paths]
#     873 if not paths:
# --> 874     raise OSError("no files to open")
#     876 if combine == "nested":
#     877     if isinstance(concat_dim, (str, DataArray)) or concat_dim is None:
#
# OSError: no files to open

# %%
f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/CMIP/*.nc'){gcms}/historical/{variants}/day/pr/NZ_Domain/*.nc'
# Out:
# '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/CMIP/*/MPI-ESM1-2-HR/historical/r1i1p1f1/day/pr/NZ_Domain/*.nc'

# %%
historical_run = xr.open_mfdataset(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/CMIP/*/{gcms}/historical/{variants}/day/pr/NZ_Domain/*/pr*{gcms}*{variants}_*_pr_v280125.nc')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[546], line 1
# ----> 1 historical_run = xr.open_mfdataset(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/CMIP/*/{gcms}/historical/{variants}/day/pr/NZ_Domain/*/pr*{gcms}*{variants}_*_pr_v280125.nc')
#
# File /nesi/project/niwa00018/rampaln/envs/ml_env_v2/lib/python3.8/site-packages/xarray/backends/api.py:874, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     871     paths = [str(p) if isinstance(p, Path) else p for p in paths]
#     873 if not paths:
# --> 874     raise OSError("no files to open")
#     876 if combine == "nested":
#     877     if isinstance(concat_dim, (str, DataArray)) or concat_dim is None:
#
# OSError: no files to open

# %%
f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/CMIP/*/{gcms}/historical/{variants}/day/pr/NZ_Domain/v20190429/pr_CMIP_*_{gcms}_historical_{variants}_day_NZ12km_NIWA-REMS_pr_v280125.nc'
# Out:
# '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/CMIP/*/MPI-ESM1-2-HR/historical/r1i1p1f1/day/pr/NZ_Domain/v20190429/pr_CMIP_*_MPI-ESM1-2-HR_historical_r1i1p1f1_day_NZ12km_NIWA-REMS_pr_v280125.nc'

# %%
rolling_max = df1.pr.groupby('time.year').max()#.rolling(year =5).mean()

# %%
z = rolling_max.interp(lat =-39, lon =176, method ='nearest').to_pandas()

# %%
coefficients = np.polyfit(z.index.ravel(), z.values.ravel(), 3)

# Create a polynomial function from the coefficients
polynomial = np.poly1d(coefficients)

# Generate x values for plotting the polynomial curve
x_fit = np.linspace(z.index.ravel().min(), z.index.ravel().max(), 500)
y_fit = polynomial(x_fit)
# Out:
# /tmp/ipykernel_177009/790876850.py:1: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   coefficients = np.polyfit(z.index.ravel(), z.values.ravel(), 3)
# /tmp/ipykernel_177009/790876850.py:7: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   x_fit = np.linspace(z.index.ravel().min(), z.index.ravel().max(), 500)

# %%
plt.plot(x_fit, y_fit)
plt.plot(z.index.ravel(), z.values.ravel())
# Out:
# /tmp/ipykernel_177009/1620391204.py:2: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   plt.plot(z.index.ravel(), z.values.ravel())

# %%
data_reconstructed = pca.inverse_transform(data_pca)
data_reconstructed.shape
# Out:
# (20, 11491)

# %%
data_pca
# Out:
# array([[-1013.32316776,  -373.95569057],
#        [  999.15454602,     5.43119955],
#        [  133.71009589,  -621.00918851],
#        [  685.12216503,     2.36997911],
#        [ -425.50658375,  -414.05131606],
#        [ -934.33564153,   177.76283681],
#        [  111.09167659,   901.03688855],
#        [ -311.61844112,  -269.23831649],
#        [-1472.91489635,  -495.2644406 ],
#        [ -573.00159241,   474.08374743],
#        [-1222.06378098,   138.43702003],
#        [ 2209.51481415,  -227.49525606],
#        [ 1445.48178007,  -737.12580305],
#        [  719.33462617,  1098.21001898],
#        [  134.5662823 ,  -145.70148708],
#        [ -413.61948532,   275.05686288],
#        [ -977.95568065,  -136.45241342],
#        [  306.37732693,  1334.32519389],
#        [  446.31680791,  -904.88591815],
#        [  153.66914878,   -81.53391723]])

# %%
from sk

# %%
fig, ax = plt.subplots()
ax.scatter(concat_djf.PR.mean(["latitude","longitude"]).values.ravel(), concat_jja.PR.mean(["latitude","longitude"]).values.ravel(), color ='r', s =100, fc ='white')
ax.set_xlim(-15, 25)
ax.set_ylim(-15, 25)
# Out:
# (-15.0, 25.0)

# %%
# Out:
# <xarray.Dataset>
# Dimensions:  (GCM: 20)
# Coordinates:
#   * GCM      (GCM) <U16 'MPI-ESM1-2-HR' 'TaiESM1' ... 'NorESM2-MM'
# Data variables:
#     PR       (GCM) float64 -1.046 11.82 7.898 10.36 ... -3.603 5.754 10.21 6.879

# %%
concat_future.plot(col

# %%
# Inidices are not finished 
# with internal varibility we will finish the indices

# %%
files_ai = glob.glob(r'/nesi/nobackup/niwa03712/CCAM_Indicators/output/ssp370/static_maps/TX/*_fp2080-2099_bp1986-2005_DJF_NZ12km.nc')
dfs = []
for file in files_ai:
    df = xr.open_dataset(file)
    dfs.append(df.squeeze().drop("time"))
concat_TX = xr.concat(dfs, dim ="GCM")
gcm = [files[i].split('_')[5] for i in range(len(files))]

# %%
concat_future.PR.plot(col ="GCM", col_wrap =5, cmap ='BrBG')

# %%
season = 'ANN'
files_ai = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/ssp370/static_maps/PR/*_fp2080-2099_bp1986-2005_{season}_NZ12km.nc')
dfs = []
for file in files_ai:
    df = xr.open_dataset(file)
    dfs.append(df.squeeze().drop("time"))
concat_future = xr.concat(dfs, dim ="GCM")
gcm = [files_ai[i].split('_')[6] for i in range(len(files_ai))]
concat_future['GCM'] = (('GCM'), gcm)

files_ai = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/PR/*bp1986-2005_{season}_NZ12km.nc')
dfs = []
for file in files_ai:
    df = xr.open_dataset(file)
    dfs.append(df.squeeze().drop("time"))
concat_base = xr.concat(dfs, dim ="GCM")
gcm = [files_ai[i].split('_')[6] for i in range(len(files_ai))]
concat_base['GCM'] = (('GCM'), gcm)

concat_jja = 100 * concat_future/concat_base

# %%
files_ai = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/ssp370/static_maps/TX/*_fp2080-2099_bp1986-2005_{season}_NZ12km.nc')

# %%
len(glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/ssp370/static_maps/TX/*_fp2080-2099_bp1986-2005_{season}_NZ12km.nc'))
# Out:
# 13

# %%
season = 'ANN'
files_ai = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/ssp370/static_maps/TX/*_fp2080-2099_bp1986-2005_{season}_NZ12km.nc')
dfs = []
for file in files_ai:
    df = xr.open_dataset(file)
    dfs.append(df.squeeze().drop("time"))
concat_future = xr.concat(dfs, dim ="GCM")
gcm = [files_ai[i].split('_')[4] for i in range(len(files_ai))]
concat_future['GCM'] = (('GCM'), gcm)

files_ai = glob.glob(f'/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/*bp1986-2005_{season}_NZ12km.nc')
dfs = []
for file in files_ai:
    df = xr.open_dataset(file)
    dfs.append(df.squeeze().drop("time"))
concat_base = xr.concat(dfs, dim ="GCM")
gcm = [files_ai[i].split('_')[4] for i in range(len(files_ai))]
concat_base['GCM'] = (('GCM'), gcm)

concat_TX = 100 * concat_future/concat_base
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[591], line 20
#      17 gcm = [files_ai[i].split('_')[4] for i in range(len(files_ai))]
#      18 concat_base['GCM'] = (('GCM'), gcm)
# ---> 20 concat_TX = 100 * concat_future/concat_base
#
# File /nesi/project/niwa00018/rampaln/envs/ml_env_v2/lib/python3.8/site-packages/xarray/core/_typed_ops.py:28, in DatasetOpsMixin.__truediv__(self, other)
#      27 def __truediv__(self, other):
# ---> 28     return self._binary_op(other, operator.truediv)
#
# File /nesi/project/niwa00018/rampaln/envs/ml_env_v2/lib/python3.8/site-packages/xarray/core/dataset.py:5691, in Dataset._binary_op(self, other, f, reflexive, join)
#    5689 align_type = OPTIONS["arithmetic_join"] if join is None else join
#    5690 if isinstance(other, (DataArray, Dataset)):
# -> 5691     self, other = align(self, other, join=align_type, copy=False)
#    5692 g = f if not reflexive else lambda x, y: f(y, x)
#    5693 ds = self._calculate_binary_op(g, other, join=align_type)
#
# File /nesi/project/niwa00018/rampaln/envs/ml_env_v2/lib/python3.8/site-packages/xarray/core/alignment.py:358, in align(join, copy, indexes, exclude, fill_value, *objects)
#     356     new_obj = obj.copy(deep=copy)
#     357 else:
# --> 358     new_obj = obj.reindex(
#     359         copy=copy, fill_value=fill_value, indexers=valid_indexers
#     360     )
#     361 new_obj.encoding = obj.encoding
#     362 result.append(new_obj)
#
# File /nesi/project/niwa00018/rampaln/envs/ml_env_v2/lib/python3.8/site-packages/xarray/core/dataset.py:2909, in Dataset.reindex(self, indexers, method, tolerance, copy, fill_value, **indexers_kwargs)
#    2709 def reindex(
#    2710     self,
#    2711     indexers: Mapping[Hashable, Any] = None,
#    (...)
#    2716     **indexers_kwargs: Any,
#    2717 ) -> "Dataset":
#    2718     """Conform this object onto a new set of indexes, filling in
#    2719     missing values with ``fill_value``. The default fill value is NaN.
#    2720
#    (...)
#    2907
#    2908     """
# -> 2909     return self._reindex(
#    2910         indexers,
#    2911         method,
#    2912         tolerance,
#    2913         copy,
#    2914         fill_value,
#    2915         sparse=False,
#    2916         **indexers_kwargs,
#    2917     )
#
# File /nesi/project/niwa00018/rampaln/envs/ml_env_v2/lib/python3.8/site-packages/xarray/core/dataset.py:2938, in Dataset._reindex(self, indexers, method, tolerance, copy, fill_value, sparse, **indexers_kwargs)
#    2935 if bad_dims:
#    2936     raise ValueError(f"invalid reindex dimensions: {bad_dims}")
# -> 2938 variables, indexes = alignment.reindex_variables(
#    2939     self.variables,
#    2940     self.sizes,
#    2941     self.xindexes,
#    2942     indexers,
#    2943     method,
#    2944     tolerance,
#    2945     copy=copy,
#    2946     fill_value=fill_value,
#    2947     sparse=sparse,
#    2948 )
#    2949 coord_names = set(self._coord_names)
#    2950 coord_names.update(indexers)
#
# File /nesi/project/niwa00018/rampaln/envs/ml_env_v2/lib/python3.8/site-packages/xarray/core/alignment.py:570, in reindex_variables(variables, sizes, indexes, indexers, method, tolerance, copy, fill_value, sparse)
#     567 index = indexes[dim].to_pandas_index()
#     569 if not index.is_unique:
# --> 570     raise ValueError(
#     571         f"cannot reindex or align along dimension {dim!r} because the "
#     572         "index has duplicate values"
#     573     )
#     575 int_indexer = get_indexer_nd(index, target, method, tolerance)
#     577 # We uses negative values from get_indexer_nd to signify
#     578 # values that are missing in the index.
#
# ValueError: cannot reindex or align along dimension 'GCM' because the index has duplicate values

# %%
files_ai
# Out:
# ['/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_ACCESS-ESM1-5_CCAM_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_MPI-ESM1-2-HR_CCAM_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_CMCC-ESM2_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_CMCC-CM2-SR5_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_NorESM2-LM_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_EC-Earth3-Veg_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_IPSL-CM6A-LR_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_EC-Earth3_CCAM_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_MPI-ESM1-2-LR_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_INM-CM4-8_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_CanESM5_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_MPI-ESM1-2-HR_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_INM-CM4-8_CCAM_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_ACCESS-CM2_CCAM_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_IITM-ESM_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_EC-Earth3_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_TaiESM1_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_INM-CM5-0_CCAM_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_EC-Earth3-Veg-LR_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_INM-CM5-0_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_GISS-E2-1-G_CCAM_base_bp1986-2005_ANN_NZ12km.nc',
#  '/nesi/nobackup/niwa03712/ML_Downscaled_CMIP6/NIWA-REMS_indicators/output/historical/static_maps/TX/TX_historical_NorESM2-MM_r1i1p1f1_base_bp1986-2005_ANN_NZ12km.nc']

# %%
concat_jja
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 243, latitude: 260, GCM: 20)
# Coordinates:
#   * longitude  (longitude) float64 166.4 166.5 166.5 166.6 ... 178.4 178.5 178.5
#   * latitude   (latitude) float64 -34.38 -34.42 -34.47 ... -47.22 -47.28 -47.33
#   * GCM        (GCM) <U10 'maps/PR/PR' 'maps/PR/PR' ... 'maps/PR/PR'
# Data variables:
#     PR         (GCM, latitude, longitude) float64 nan nan nan ... nan nan nan
